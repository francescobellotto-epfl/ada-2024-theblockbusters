# %% [markdown]
# # Wikidata Scraping with SPARQL
#
# In this notebook, we scrape data from [Wikidata](https://www.wikidata.org) using the **Wikidata Query Service**. We use **SPARQL** queries to download data directly from Wikidata.

# %%
import pandas as pd
import numpy as np
import time
import requests

from wikidata_scraping import download_wikidata_sparql_csv

DATA_PATH = "./../../Data/"

# %% [markdown]
# # Wikidata scraping - Movies

# %%
# Define query to search for movies based on their imdbID

generic_query = """
SELECT ?imdbID
       (SAMPLE(?wikidataID) AS ?wikidataID)
       (SAMPLE(?freebaseID) AS ?freebaseID)
       (SAMPLE(?wikipediaLink) AS ?wikipediaLink)
       (SAMPLE(?title) AS ?title)
       (SAMPLE(?description) AS ?description)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?runtimes), ",", ""); SEPARATOR=",") AS ?runtime)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?releaseDates), ",", ""); SEPARATOR=",") AS ?releaseDate)
       (GROUP_CONCAT(DISTINCT REPLACE(?genreLabel, ",", ""); SEPARATOR=",") AS ?genres)
       (GROUP_CONCAT(DISTINCT REPLACE(?countryLabel, ",", ""); SEPARATOR=",") AS ?countries)
       (GROUP_CONCAT(DISTINCT REPLACE(?languageLabel, ",", ""); SEPARATOR=",") AS ?languages)
       (GROUP_CONCAT(DISTINCT REPLACE(?companyLabel, ",", ""); SEPARATOR=",") AS ?productionCompanies)
WHERE {
  VALUES ?imdbID {
|
  }
  
  # ?item wdt:P345 ?imdbID .
  BIND(STR(?item) AS ?wikidataID)

  OPTIONAL { ?item wdt:P646 ?freebaseID }
  OPTIONAL { ?item wdt:P136 ?genre . ?genre rdfs:label ?genreLabel FILTER(LANG(?genreLabel) = "en") }
  OPTIONAL { ?item wdt:P495 ?country . ?country rdfs:label ?countryLabel FILTER(LANG(?countryLabel) = "en") }
  OPTIONAL { ?item wdt:P364 ?language . ?language rdfs:label ?languageLabel FILTER(LANG(?languageLabel) = "en") }
  OPTIONAL { ?item wdt:P272 ?company . ?company rdfs:label ?companyLabel FILTER(LANG(?companyLabel) = "en") }
  OPTIONAL { ?item wdt:P577 ?releaseDates }
  OPTIONAL { ?item wdt:P2047 ?runtimes }
  
  OPTIONAL {
    # ?wikipediaLink schema:about ?item ;
                   schema:inLanguage "en" ;
                   schema:isPartOf <https://en.wikipedia.org/> .
  }

  # ?item rdfs:label ?title FILTER(LANG(?title) = "en") .
  OPTIONAL { ?item schema:description ?description FILTER(LANG(?description) = "en") }
}
GROUP BY ?imdbID
"""

# %%
# We run the above defined SPARQL query on groups of 120 imdbIDs, the results are saved in temporary files

imdb_ids = pd.read_csv(DATA_PATH + "movies_imdb_tmdb.tsv", sep='\t')['imdb_id_movie'].values

temp_files_name = "tempFiles/wikidata_imdbID_temp_"

n = len(imdb_ids)
step = 120

c = 1
low = step*(c-1)
while low < n:
    up = min(low + step, n)

    ids_string = "\n".join([f"\"{imdb_ids[i]}\"" for i in range(low,up)])
    
    query = generic_query.replace("|", ids_string)
    
    success = download_wikidata_sparql_csv(query, f"{DATA_PATH}{temp_files_name}{c:06d}.csv")
    
    if success:
        low = up
        c += 1
        print(f"{up}/{n} done")
    else:
        print(f"{low} - {up} to redo")

    time.sleep(0.25)
# Out:
# 120/381216 done
# 240/381216 done
# 360/381216 done
# 480/381216 done
# 600/381216 done
# 720/381216 done
# 840/381216 done
# 960/381216 done
# 1080/381216 done
# 1200/381216 done
# 1320/381216 done
# 1440/381216 done
# 1560/381216 done
# 1680/381216 done
# 1800/381216 done
# 1920/381216 done
# 2040/381216 done
# 2160/381216 done
# 2280/381216 done
# 2400/381216 done
# 2520/381216 done
# 2640/381216 done
# 2760/381216 done
# 2880/381216 done
# 3000/381216 done
# 3120/381216 done
# 3240/381216 done
# 3360/381216 done
# 3480/381216 done
# 3600/381216 done
# 3720/381216 done
# 3840/381216 done
# 3960/381216 done
# 4080/381216 done
# 4200/381216 done
# 4320/381216 done
# 4440/381216 done
# 4560/381216 done
# 4680/381216 done
# 4800/381216 done
# 4920/381216 done
# 5040/381216 done
# 5160/381216 done
# 5280/381216 done
# 5400/381216 done
# 5520/381216 done
# 5640/381216 done
# 5760/381216 done
# 5880/381216 done
# 6000/381216 done
# 6120/381216 done
# 6240/381216 done
# 6360/381216 done
# 6480/381216 done
# 6600/381216 done
# 6720/381216 done
# 6840/381216 done
# 6960/381216 done
# 7080/381216 done
# 7200/381216 done
# 7320/381216 done
# 7440/381216 done
# 7560/381216 done
# 7680/381216 done
# 7800/381216 done
# 7920/381216 done
# 8040/381216 done
# 8160/381216 done
# 8280/381216 done
# 8400/381216 done
# 8520/381216 done
# 8640/381216 done
# 8760/381216 done
# 8880/381216 done
# 9000/381216 done
# 9120/381216 done
# 9240/381216 done
# 9360/381216 done
# 9480/381216 done
# 9600/381216 done
# 9720/381216 done
# 9840/381216 done
# 9960/381216 done
# 10080/381216 done
# 10200/381216 done
# 10320/381216 done
# 10440/381216 done
# 10560/381216 done
# 10680/381216 done
# 10800/381216 done
# 10920/381216 done
# 11040/381216 done
# 11160/381216 done
# 11280/381216 done
# 11400/381216 done
# 11520/381216 done
# 11640/381216 done
# 11760/381216 done
# 11880/381216 done
# 12000/381216 done
# 12120/381216 done
# 12240/381216 done
# 12360/381216 done
# 12480/381216 done
# 12600/381216 done
# 12720/381216 done
# 12840/381216 done
# 12960/381216 done
# 13080/381216 done
# 13200/381216 done
# 13320/381216 done
# 13440/381216 done
# 13560/381216 done
# 13680/381216 done
# 13800/381216 done
# 13920/381216 done
# 14040/381216 done
# 14160/381216 done
# 14280/381216 done
# 14400/381216 done
# 14520/381216 done
# 14640/381216 done
# 14760/381216 done
# 14880/381216 done
# 15000/381216 done
# 15120/381216 done
# 15240/381216 done
# 15360/381216 done
# 15480/381216 done
# 15600/381216 done
# 15720/381216 done
# 15840/381216 done
# 15960/381216 done
# 16080/381216 done
# 16200/381216 done
# 16320/381216 done
# 16440/381216 done
# 16560/381216 done
# 16680/381216 done
# 16800/381216 done
# 16920/381216 done
# 17040/381216 done
# 17160/381216 done
# 17280/381216 done
# 17400/381216 done
# 17520/381216 done
# 17640/381216 done
# 17760/381216 done
# 17880/381216 done
# 18000/381216 done
# 18120/381216 done
# 18240/381216 done
# 18360/381216 done
# 18480/381216 done
# 18600/381216 done
# 18720/381216 done
# 18840/381216 done
# 18960/381216 done
# 19080/381216 done
# 19200/381216 done
# 19320/381216 done
# 19440/381216 done
# 19560/381216 done
# 19680/381216 done
# 19800/381216 done
# 19920/381216 done
# 20040/381216 done
# 20160/381216 done
# 20280/381216 done
# 20400/381216 done
# 20520/381216 done
# 20640/381216 done
# 20760/381216 done
# 20880/381216 done
# 21000/381216 done
# 21120/381216 done
# 21240/381216 done
# 21360/381216 done
# 21480/381216 done
# 21600/381216 done
# 21720/381216 done
# 21840/381216 done
# 21960/381216 done
# 22080/381216 done
# 22200/381216 done
# 22320/381216 done
# 22440/381216 done
# 22560/381216 done
# 22680/381216 done
# 22800/381216 done
# 22920/381216 done
# 23040/381216 done
# 23160/381216 done
# 23280/381216 done
# 23400/381216 done
# 23520/381216 done
# 23640/381216 done
# 23760/381216 done
# 23880/381216 done
# 24000/381216 done
# 24120/381216 done
# 24240/381216 done
# 24360/381216 done
# 24480/381216 done
# 24600/381216 done
# 24720/381216 done
# 24840/381216 done
# 24960/381216 done
# 25080/381216 done
# 25200/381216 done
# 25320/381216 done
# 25440/381216 done
# 25560/381216 done
# 25680/381216 done
# 25800/381216 done
# 25920/381216 done
# 26040/381216 done
# 26160/381216 done
# 26280/381216 done
# 26400/381216 done
# 26520/381216 done
# 26640/381216 done
# 26760/381216 done
# 26880/381216 done
# 27000/381216 done
# 27120/381216 done
# 27240/381216 done
# 27360/381216 done
# 27480/381216 done
# 27600/381216 done
# 27720/381216 done
# 27840/381216 done
# 27960/381216 done
# 28080/381216 done
# 28200/381216 done
# 28320/381216 done
# 28440/381216 done
# 28560/381216 done
# 28680/381216 done
# 28800/381216 done
# 28920/381216 done
# 29040/381216 done
# 29160/381216 done
# 29280/381216 done
# 29400/381216 done
# 29520/381216 done
# 29640/381216 done
# 29760/381216 done
# 29880/381216 done
# 30000/381216 done
# 30120/381216 done
# 30240/381216 done
# 30360/381216 done
# 30480/381216 done
# 30600/381216 done
# 30720/381216 done
# 30840/381216 done
# 30960/381216 done
# 31080/381216 done
# 31200/381216 done
# 31320/381216 done
# 31440/381216 done
# 31560/381216 done
# 31680/381216 done
# 31800/381216 done
# 31920/381216 done
# 32040/381216 done
# 32160/381216 done
# 32280/381216 done
# 32400/381216 done
# 32520/381216 done
# 32640/381216 done
# 32760/381216 done
# 32880/381216 done
# 33000/381216 done
# 33120/381216 done
# 33240/381216 done
# 33360/381216 done
# 33480/381216 done
# 33600/381216 done
# 33720/381216 done
# 33840/381216 done
# 33960/381216 done
# 34080/381216 done
# 34200/381216 done
# 34320/381216 done
# 34440/381216 done
# 34560/381216 done
# 34680/381216 done
# 34800/381216 done
# 34920/381216 done
# 35040/381216 done
# 35160/381216 done
# 35280/381216 done
# 35400/381216 done
# 35520/381216 done
# 35640/381216 done
# 35760/381216 done
# 35880/381216 done
# 36000/381216 done
# 36120/381216 done
# 36240/381216 done
# 36360/381216 done
# 36480/381216 done
# 36600/381216 done
# 36720/381216 done
# 36840/381216 done
# 36960/381216 done
# 37080/381216 done
# 37200/381216 done
# 37320/381216 done
# 37440/381216 done
# 37560/381216 done
# 37680/381216 done
# 37800/381216 done
# 37920/381216 done
# 38040/381216 done
# 38160/381216 done
# 38280/381216 done
# 38400/381216 done
# 38520/381216 done
# 38640/381216 done
# 38760/381216 done
# 38880/381216 done
# 39000/381216 done
# 39120/381216 done
# 39240/381216 done
# 39360/381216 done
# 39480/381216 done
# 39600/381216 done
# 39720/381216 done
# 39840/381216 done
# 39960/381216 done
# 40080/381216 done
# 40200/381216 done
# 40320/381216 done
# 40440/381216 done
# 40560/381216 done
# 40680/381216 done
# 40800/381216 done
# 40920/381216 done
# 41040/381216 done
# 41160/381216 done
# 41280/381216 done
# 41400/381216 done
# 41520/381216 done
# 41640/381216 done
# 41760/381216 done
# 41880/381216 done
# 42000/381216 done
# 42120/381216 done
# 42240/381216 done
# 42360/381216 done
# 42480/381216 done
# 42600/381216 done
# 42720/381216 done
# 42840/381216 done
# 42960/381216 done
# 43080/381216 done
# 43200/381216 done
# 43320/381216 done
# 43440/381216 done
# 43560/381216 done
# 43680/381216 done
# 43800/381216 done
# 43920/381216 done
# 44040/381216 done
# 44160/381216 done
# 44280/381216 done
# 44400/381216 done
# 44520/381216 done
# 44640/381216 done
# 44760/381216 done
# 44880/381216 done
# 45000/381216 done
# 45120/381216 done
# 45240/381216 done
# 45360/381216 done
# 45480/381216 done
# 45600/381216 done
# 45720/381216 done
# 45840/381216 done
# 45960/381216 done
# 46080/381216 done
# 46200/381216 done
# 46320/381216 done
# 46440/381216 done
# 46560/381216 done
# 46680/381216 done
# 46800/381216 done
# 46920/381216 done
# 47040/381216 done
# 47160/381216 done
# 47280/381216 done
# 47400/381216 done
# 47520/381216 done
# 47640/381216 done
# 47760/381216 done
# 47880/381216 done
# 48000/381216 done
# 48120/381216 done
# 48240/381216 done
# 48360/381216 done
# 48480/381216 done
# 48600/381216 done
# 48720/381216 done
# 48840/381216 done
# 48960/381216 done
# 49080/381216 done
# 49200/381216 done
# 49320/381216 done
# 49440/381216 done
# 49560/381216 done
# 49680/381216 done
# 49800/381216 done
# 49920/381216 done
# 50040/381216 done
# 50160/381216 done
# 50280/381216 done
# 50400/381216 done
# 50520/381216 done
# 50640/381216 done
# 50760/381216 done
# 50880/381216 done
# 51000/381216 done
# 51120/381216 done
# 51240/381216 done
# 51360/381216 done
# 51480/381216 done
# 51600/381216 done
# 51720/381216 done
# 51840/381216 done
# 51960/381216 done
# 52080/381216 done
# 52200/381216 done
# 52320/381216 done
# 52440/381216 done
# 52560/381216 done
# 52680/381216 done
# 52800/381216 done
# 52920/381216 done
# 53040/381216 done
# 53160/381216 done
# 53280/381216 done
# 53400/381216 done
# 53520/381216 done
# 53640/381216 done
# 53760/381216 done
# 53880/381216 done
# 54000/381216 done
# 54120/381216 done
# 54240/381216 done
# 54360/381216 done
# 54480/381216 done
# 54600/381216 done
# 54720/381216 done
# 54840/381216 done
# 54960/381216 done
# 55080/381216 done
# 55200/381216 done
# 55320/381216 done
# 55440/381216 done
# 55560/381216 done
# 55680/381216 done
# 55800/381216 done
# 55920/381216 done
# 56040/381216 done
# 56160/381216 done
# 56280/381216 done
# 56400/381216 done
# 56520/381216 done
# 56640/381216 done
# 56760/381216 done
# 56880/381216 done
# 57000/381216 done
# 57120/381216 done
# 57240/381216 done
# 57360/381216 done
# 57480/381216 done
# 57600/381216 done
# 57720/381216 done
# 57840/381216 done
# 57960/381216 done
# 58080/381216 done
# 58200/381216 done
# 58320/381216 done
# 58440/381216 done
# 58560/381216 done
# 58680/381216 done
# 58800/381216 done
# 58920/381216 done
# 59040/381216 done
# 59160/381216 done
# 59280/381216 done
# 59400/381216 done
# 59520/381216 done
# 59640/381216 done
# 59760/381216 done
# 59880/381216 done
# 60000/381216 done
# 60120/381216 done
# 60240/381216 done
# 60360/381216 done
# 60480/381216 done
# 60600/381216 done
# 60720/381216 done
# 60840/381216 done
# 60960/381216 done
# 61080/381216 done
# 61200/381216 done
# 61320/381216 done
# 61440/381216 done
# 61560/381216 done
# 61680/381216 done
# 61800/381216 done
# 61920/381216 done
# 62040/381216 done
# 62160/381216 done
# 62280/381216 done
# 62400/381216 done
# 62520/381216 done
# 62640/381216 done
# 62760/381216 done
# 62880/381216 done
# 63000/381216 done
# 63120/381216 done
# 63240/381216 done
# 63360/381216 done
# 63480/381216 done
# 63600/381216 done
# 63720/381216 done
# 63840/381216 done
# 63960/381216 done
# 64080/381216 done
# 64200/381216 done
# 64320/381216 done
# 64440/381216 done
# 64560/381216 done
# 64680/381216 done
# 64800/381216 done
# 64920/381216 done
# 65040/381216 done
# 65160/381216 done
# 65280/381216 done
# 65400/381216 done
# 65520/381216 done
# 65640/381216 done
# 65760/381216 done
# 65880/381216 done
# 66000/381216 done
# 66120/381216 done
# 66240/381216 done
# 66360/381216 done
# 66480/381216 done
# 66600/381216 done
# 66720/381216 done
# 66840/381216 done
# 66960/381216 done
# 67080/381216 done
# 67200/381216 done
# 67320/381216 done
# 67440/381216 done
# 67560/381216 done
# 67680/381216 done
# 67800/381216 done
# 67920/381216 done
# 68040/381216 done
# 68160/381216 done
# 68280/381216 done
# 68400/381216 done
# 68520/381216 done
# 68640/381216 done
# 68760/381216 done
# 68880/381216 done
# 69000/381216 done
# 69120/381216 done
# 69240/381216 done
# 69360/381216 done
# 69480/381216 done
# 69600/381216 done
# 69720/381216 done
# 69840/381216 done
# 69960/381216 done
# 70080/381216 done
# 70200/381216 done
# 70320/381216 done
# 70440/381216 done
# 70560/381216 done
# 70680/381216 done
# 70800/381216 done
# 70920/381216 done
# 71040/381216 done
# 71160/381216 done
# 71280/381216 done
# 71400/381216 done
# 71520/381216 done
# 71640/381216 done
# 71760/381216 done
# 71880/381216 done
# 72000/381216 done
# 72120/381216 done
# 72240/381216 done
# 72360/381216 done
# 72480/381216 done
# 72600/381216 done
# 72720/381216 done
# 72840/381216 done
# 72960/381216 done
# 73080/381216 done
# 73200/381216 done
# 73320/381216 done
# 73440/381216 done
# 73560/381216 done
# 73680/381216 done
# 73800/381216 done
# 73920/381216 done
# 74040/381216 done
# 74160/381216 done
# 74280/381216 done
# 74400/381216 done
# 74520/381216 done
# 74640/381216 done
# 74760/381216 done
# 74880/381216 done
# 75000/381216 done
# 75120/381216 done
# 75240/381216 done
# 75360/381216 done
# 75480/381216 done
# 75600/381216 done
# 75720/381216 done
# 75840/381216 done
# 75960/381216 done
# 76080/381216 done
# 76200/381216 done
# 76320/381216 done
# 76440/381216 done
# 76560/381216 done
# 76680/381216 done
# 76800/381216 done
# 76920/381216 done
# 77040/381216 done
# 77160/381216 done
# 77280/381216 done
# 77400/381216 done
# 77520/381216 done
# 77640/381216 done
# 77760/381216 done
# 77880/381216 done
# 78000/381216 done
# 78120/381216 done
# 78240/381216 done
# 78360/381216 done
# 78480/381216 done
# 78600/381216 done
# 78720/381216 done
# 78840/381216 done
# 78960/381216 done
# 79080/381216 done
# 79200/381216 done
# 79320/381216 done
# 79440/381216 done
# 79560/381216 done
# 79680/381216 done
# 79800/381216 done
# 79920/381216 done
# 80040/381216 done
# 80160/381216 done
# 80280/381216 done
# 80400/381216 done
# 80520/381216 done
# 80640/381216 done
# 80760/381216 done
# 80880/381216 done
# 81000/381216 done
# 81120/381216 done
# 81240/381216 done
# 81360/381216 done
# 81480/381216 done
# 81600/381216 done
# 81720/381216 done
# 81840/381216 done
# 81960/381216 done
# 82080/381216 done
# 82200/381216 done
# 82320/381216 done
# 82440/381216 done
# 82560/381216 done
# 82680/381216 done
# 82800/381216 done
# 82920/381216 done
# 83040/381216 done
# 83160/381216 done
# 83280/381216 done
# 83400/381216 done
# 83520/381216 done
# 83640/381216 done
# 83760/381216 done
# 83880/381216 done
# 84000/381216 done
# 84120/381216 done
# 84240/381216 done
# 84360/381216 done
# 84480/381216 done
# 84600/381216 done
# 84720/381216 done
# 84840/381216 done
# 84960/381216 done
# 85080/381216 done
# 85200/381216 done
# 85320/381216 done
# 85440/381216 done
# 85560/381216 done
# 85680/381216 done
# 85800/381216 done
# 85920/381216 done
# 86040/381216 done
# 86160/381216 done
# 86280/381216 done
# 86400/381216 done
# 86520/381216 done
# 86640/381216 done
# 86760/381216 done
# 86880/381216 done
# 87000/381216 done
# 87120/381216 done
# 87240/381216 done
# 87360/381216 done
# 87480/381216 done
# 87600/381216 done
# 87720/381216 done
# 87840/381216 done
# 87960/381216 done
# 88080/381216 done
# 88200/381216 done
# 88320/381216 done
# 88440/381216 done
# 88560/381216 done
# 88680/381216 done
# 88800/381216 done
# 88920/381216 done
# 89040/381216 done
# 89160/381216 done
# 89280/381216 done
# 89400/381216 done
# 89520/381216 done
# 89640/381216 done
# 89760/381216 done
# 89880/381216 done
# 90000/381216 done
# 90120/381216 done
# 90240/381216 done
# 90360/381216 done
# 90480/381216 done
# 90600/381216 done
# 90720/381216 done
# 90840/381216 done
# 90960/381216 done
# 91080/381216 done
# 91200/381216 done
# 91320/381216 done
# 91440/381216 done
# 91560/381216 done
# 91680/381216 done
# 91800/381216 done
# 91920/381216 done
# 92040/381216 done
# 92160/381216 done
# 92280/381216 done
# 92400/381216 done
# 92520/381216 done
# 92640/381216 done
# 92760/381216 done
# 92880/381216 done
# 93000/381216 done
# 93120/381216 done
# 93240/381216 done
# 93360/381216 done
# 93480/381216 done
# 93600/381216 done
# 93720/381216 done
# 93840/381216 done
# 93960/381216 done
# 94080/381216 done
# 94200/381216 done
# 94320/381216 done
# 94440/381216 done
# 94560/381216 done
# 94680/381216 done
# 94800/381216 done
# 94920/381216 done
# 95040/381216 done
# 95160/381216 done
# 95280/381216 done
# 95400/381216 done
# 95520/381216 done
# 95640/381216 done
# 95760/381216 done
# 95880/381216 done
# 96000/381216 done
# 96120/381216 done
# 96240/381216 done
# 96360/381216 done
# 96480/381216 done
# 96600/381216 done
# 96720/381216 done
# 96840/381216 done
# 96960/381216 done
# 97080/381216 done
# 97200/381216 done
# 97320/381216 done
# 97440/381216 done
# 97560/381216 done
# 97680/381216 done
# 97800/381216 done
# 97920/381216 done
# 98040/381216 done
# 98160/381216 done
# 98280/381216 done
# 98400/381216 done
# 98520/381216 done
# 98640/381216 done
# 98760/381216 done
# 98880/381216 done
# 99000/381216 done
# 99120/381216 done
# 99240/381216 done
# 99360/381216 done
# 99480/381216 done
# 99600/381216 done
# 99720/381216 done
# 99840/381216 done
# 99960/381216 done
# 100080/381216 done
# 100200/381216 done
# 100320/381216 done
# 100440/381216 done
# 100560/381216 done
# 100680/381216 done
# 100800/381216 done
# 100920/381216 done
# 101040/381216 done
# 101160/381216 done
# 101280/381216 done
# 101400/381216 done
# 101520/381216 done
# 101640/381216 done
# 101760/381216 done
# 101880/381216 done
# 102000/381216 done
# 102120/381216 done
# 102240/381216 done
# 102360/381216 done
# 102480/381216 done
# 102600/381216 done
# 102720/381216 done
# 102840/381216 done
# 102960/381216 done
# 103080/381216 done
# 103200/381216 done
# 103320/381216 done
# 103440/381216 done
# 103560/381216 done
# 103680/381216 done
# 103800/381216 done
# 103920/381216 done
# 104040/381216 done
# 104160/381216 done
# 104280/381216 done
# 104400/381216 done
# 104520/381216 done
# 104640/381216 done
# 104760/381216 done
# 104880/381216 done
# 105000/381216 done
# 105120/381216 done
# 105240/381216 done
# 105360/381216 done
# 105480/381216 done
# 105600/381216 done
# 105720/381216 done
# 105840/381216 done
# 105960/381216 done
# 106080/381216 done
# 106200/381216 done
# 106320/381216 done
# 106440/381216 done
# 106560/381216 done
# 106680/381216 done
# 106800/381216 done
# 106920/381216 done
# 107040/381216 done
# 107160/381216 done
# 107280/381216 done
# 107400/381216 done
# 107520/381216 done
# 107640/381216 done
# 107760/381216 done
# 107880/381216 done
# 108000/381216 done
# 108120/381216 done
# 108240/381216 done
# Error: Failed to retrieve data. Status code 429
# 108240 - 108360 to redo
# 108360/381216 done
# 108480/381216 done
# Error: Failed to retrieve data. Status code 429
# 108480 - 108600 to redo
# 108600/381216 done
# Error: Failed to retrieve data. Status code 429
# 108600 - 108720 to redo
# 108720/381216 done
# Error: Failed to retrieve data. Status code 429
# 108720 - 108840 to redo
# 108840/381216 done
# Error: Failed to retrieve data. Status code 429
# 108840 - 108960 to redo
# 108960/381216 done
# Error: Failed to retrieve data. Status code 429
# 108960 - 109080 to redo
# 109080/381216 done
# 109200/381216 done
# Error: Failed to retrieve data. Status code 429
# 109200 - 109320 to redo
# 109320/381216 done
# 109440/381216 done
# 109560/381216 done
# 109680/381216 done
# 109800/381216 done
# 109920/381216 done
# 110040/381216 done
# 110160/381216 done
# 110280/381216 done
# 110400/381216 done
# 110520/381216 done
# 110640/381216 done
# 110760/381216 done
# 110880/381216 done
# 111000/381216 done
# 111120/381216 done
# 111240/381216 done
# 111360/381216 done
# 111480/381216 done
# 111600/381216 done
# 111720/381216 done
# 111840/381216 done
# 111960/381216 done
# 112080/381216 done
# 112200/381216 done
# 112320/381216 done
# 112440/381216 done
# 112560/381216 done
# 112680/381216 done
# 112800/381216 done
# 112920/381216 done
# 113040/381216 done
# 113160/381216 done
# 113280/381216 done
# 113400/381216 done
# 113520/381216 done
# 113640/381216 done
# 113760/381216 done
# 113880/381216 done
# 114000/381216 done
# 114120/381216 done
# 114240/381216 done
# 114360/381216 done
# 114480/381216 done
# 114600/381216 done
# 114720/381216 done
# 114840/381216 done
# 114960/381216 done
# 115080/381216 done
# 115200/381216 done
# 115320/381216 done
# 115440/381216 done
# 115560/381216 done
# 115680/381216 done
# 115800/381216 done
# 115920/381216 done
# 116040/381216 done
# 116160/381216 done
# 116280/381216 done
# 116400/381216 done
# 116520/381216 done
# 116640/381216 done
# 116760/381216 done
# 116880/381216 done
# 117000/381216 done
# 117120/381216 done
# 117240/381216 done
# 117360/381216 done
# 117480/381216 done
# 117600/381216 done
# 117720/381216 done
# 117840/381216 done
# 117960/381216 done
# 118080/381216 done
# 118200/381216 done
# 118320/381216 done
# 118440/381216 done
# 118560/381216 done
# 118680/381216 done
# 118800/381216 done
# 118920/381216 done
# 119040/381216 done
# 119160/381216 done
# 119280/381216 done
# 119400/381216 done
# 119520/381216 done
# 119640/381216 done
# 119760/381216 done
# 119880/381216 done
# 120000/381216 done
# 120120/381216 done
# 120240/381216 done
# 120360/381216 done
# 120480/381216 done
# 120600/381216 done
# 120720/381216 done
# 120840/381216 done
# 120960/381216 done
# 121080/381216 done
# 121200/381216 done
# 121320/381216 done
# 121440/381216 done
# 121560/381216 done
# 121680/381216 done
# 121800/381216 done
# 121920/381216 done
# 122040/381216 done
# 122160/381216 done
# 122280/381216 done
# 122400/381216 done
# 122520/381216 done
# 122640/381216 done
# 122760/381216 done
# 122880/381216 done
# 123000/381216 done
# 123120/381216 done
# 123240/381216 done
# 123360/381216 done
# 123480/381216 done
# 123600/381216 done
# 123720/381216 done
# 123840/381216 done
# 123960/381216 done
# 124080/381216 done
# 124200/381216 done
# 124320/381216 done
# 124440/381216 done
# 124560/381216 done
# 124680/381216 done
# 124800/381216 done
# 124920/381216 done
# 125040/381216 done
# 125160/381216 done
# 125280/381216 done
# 125400/381216 done
# 125520/381216 done
# 125640/381216 done
# 125760/381216 done
# 125880/381216 done
# 126000/381216 done
# 126120/381216 done
# 126240/381216 done
# 126360/381216 done
# 126480/381216 done
# 126600/381216 done
# 126720/381216 done
# 126840/381216 done
# 126960/381216 done
# 127080/381216 done
# 127200/381216 done
# 127320/381216 done
# 127440/381216 done
# 127560/381216 done
# 127680/381216 done
# 127800/381216 done
# 127920/381216 done
# 128040/381216 done
# 128160/381216 done
# 128280/381216 done
# 128400/381216 done
# 128520/381216 done
# 128640/381216 done
# 128760/381216 done
# 128880/381216 done
# 129000/381216 done
# 129120/381216 done
# 129240/381216 done
# 129360/381216 done
# 129480/381216 done
# 129600/381216 done
# 129720/381216 done
# 129840/381216 done
# 129960/381216 done
# 130080/381216 done
# 130200/381216 done
# 130320/381216 done
# 130440/381216 done
# 130560/381216 done
# 130680/381216 done
# 130800/381216 done
# 130920/381216 done
# 131040/381216 done
# 131160/381216 done
# 131280/381216 done
# 131400/381216 done
# 131520/381216 done
# 131640/381216 done
# 131760/381216 done
# 131880/381216 done
# 132000/381216 done
# 132120/381216 done
# 132240/381216 done
# 132360/381216 done
# 132480/381216 done
# 132600/381216 done
# 132720/381216 done
# 132840/381216 done
# 132960/381216 done
# 133080/381216 done
# 133200/381216 done
# 133320/381216 done
# 133440/381216 done
# 133560/381216 done
# 133680/381216 done
# 133800/381216 done
# 133920/381216 done
# 134040/381216 done
# 134160/381216 done
# 134280/381216 done
# 134400/381216 done
# 134520/381216 done
# 134640/381216 done
# 134760/381216 done
# 134880/381216 done
# 135000/381216 done
# 135120/381216 done
# 135240/381216 done
# 135360/381216 done
# 135480/381216 done
# 135600/381216 done
# 135720/381216 done
# 135840/381216 done
# 135960/381216 done
# 136080/381216 done
# 136200/381216 done
# 136320/381216 done
# 136440/381216 done
# 136560/381216 done
# 136680/381216 done
# 136800/381216 done
# 136920/381216 done
# 137040/381216 done
# 137160/381216 done
# 137280/381216 done
# 137400/381216 done
# 137520/381216 done
# 137640/381216 done
# 137760/381216 done
# 137880/381216 done
# 138000/381216 done
# 138120/381216 done
# 138240/381216 done
# 138360/381216 done
# 138480/381216 done
# 138600/381216 done
# 138720/381216 done
# 138840/381216 done
# 138960/381216 done
# 139080/381216 done
# 139200/381216 done
# 139320/381216 done
# 139440/381216 done
# 139560/381216 done
# 139680/381216 done
# 139800/381216 done
# 139920/381216 done
# 140040/381216 done
# 140160/381216 done
# 140280/381216 done
# 140400/381216 done
# 140520/381216 done
# 140640/381216 done
# 140760/381216 done
# 140880/381216 done
# 141000/381216 done
# 141120/381216 done
# 141240/381216 done
# 141360/381216 done
# 141480/381216 done
# 141600/381216 done
# 141720/381216 done
# 141840/381216 done
# Error: Failed to retrieve data. Status code 429
# 141840 - 141960 to redo
# 141960/381216 done
# 142080/381216 done
# 142200/381216 done
# 142320/381216 done
# 142440/381216 done
# 142560/381216 done
# 142680/381216 done
# 142800/381216 done
# 142920/381216 done
# 143040/381216 done
# 143160/381216 done
# 143280/381216 done
# 143400/381216 done
# 143520/381216 done
# 143640/381216 done
# 143760/381216 done
# 143880/381216 done
# 144000/381216 done
# 144120/381216 done
# 144240/381216 done
# 144360/381216 done
# 144480/381216 done
# 144600/381216 done
# 144720/381216 done
# 144840/381216 done
# 144960/381216 done
# 145080/381216 done
# 145200/381216 done
# 145320/381216 done
# 145440/381216 done
# 145560/381216 done
# 145680/381216 done
# 145800/381216 done
# 145920/381216 done
# 146040/381216 done
# 146160/381216 done
# 146280/381216 done
# 146400/381216 done
# 146520/381216 done
# 146640/381216 done
# 146760/381216 done
# 146880/381216 done
# 147000/381216 done
# 147120/381216 done
# 147240/381216 done
# 147360/381216 done
# 147480/381216 done
# 147600/381216 done
# 147720/381216 done
# 147840/381216 done
# 147960/381216 done
# 148080/381216 done
# 148200/381216 done
# 148320/381216 done
# 148440/381216 done
# 148560/381216 done
# 148680/381216 done
# 148800/381216 done
# 148920/381216 done
# 149040/381216 done
# 149160/381216 done
# 149280/381216 done
# 149400/381216 done
# 149520/381216 done
# 149640/381216 done
# 149760/381216 done
# 149880/381216 done
# 150000/381216 done
# 150120/381216 done
# 150240/381216 done
# 150360/381216 done
# 150480/381216 done
# 150600/381216 done
# 150720/381216 done
# 150840/381216 done
# 150960/381216 done
# 151080/381216 done
# 151200/381216 done
# 151320/381216 done
# 151440/381216 done
# 151560/381216 done
# 151680/381216 done
# 151800/381216 done
# 151920/381216 done
# 152040/381216 done
# 152160/381216 done
# 152280/381216 done
# 152400/381216 done
# 152520/381216 done
# 152640/381216 done
# 152760/381216 done
# 152880/381216 done
# 153000/381216 done
# 153120/381216 done
# 153240/381216 done
# 153360/381216 done
# 153480/381216 done
# 153600/381216 done
# 153720/381216 done
# 153840/381216 done
# 153960/381216 done
# 154080/381216 done
# 154200/381216 done
# 154320/381216 done
# 154440/381216 done
# 154560/381216 done
# 154680/381216 done
# 154800/381216 done
# 154920/381216 done
# 155040/381216 done
# 155160/381216 done
# 155280/381216 done
# 155400/381216 done
# 155520/381216 done
# 155640/381216 done
# 155760/381216 done
# 155880/381216 done
# 156000/381216 done
# 156120/381216 done
# 156240/381216 done
# 156360/381216 done
# 156480/381216 done
# 156600/381216 done
# 156720/381216 done
# 156840/381216 done
# 156960/381216 done
# 157080/381216 done
# 157200/381216 done
# 157320/381216 done
# 157440/381216 done
# 157560/381216 done
# 157680/381216 done
# 157800/381216 done
# 157920/381216 done
# 158040/381216 done
# 158160/381216 done
# 158280/381216 done
# 158400/381216 done
# 158520/381216 done
# 158640/381216 done
# 158760/381216 done
# 158880/381216 done
# 159000/381216 done
# 159120/381216 done
# 159240/381216 done
# 159360/381216 done
# 159480/381216 done
# 159600/381216 done
# 159720/381216 done
# 159840/381216 done
# 159960/381216 done
# 160080/381216 done
# 160200/381216 done
# 160320/381216 done
# 160440/381216 done
# 160560/381216 done
# 160680/381216 done
# 160800/381216 done
# 160920/381216 done
# 161040/381216 done
# 161160/381216 done
# 161280/381216 done
# 161400/381216 done
# 161520/381216 done
# 161640/381216 done
# 161760/381216 done
# 161880/381216 done
# 162000/381216 done
# 162120/381216 done
# 162240/381216 done
# 162360/381216 done
# 162480/381216 done
# 162600/381216 done
# 162720/381216 done
# 162840/381216 done
# 162960/381216 done
# 163080/381216 done
# 163200/381216 done
# 163320/381216 done
# 163440/381216 done
# 163560/381216 done
# 163680/381216 done
# 163800/381216 done
# 163920/381216 done
# 164040/381216 done
# 164160/381216 done
# 164280/381216 done
# 164400/381216 done
# 164520/381216 done
# 164640/381216 done
# 164760/381216 done
# 164880/381216 done
# 165000/381216 done
# 165120/381216 done
# 165240/381216 done
# 165360/381216 done
# 165480/381216 done
# 165600/381216 done
# 165720/381216 done
# 165840/381216 done
# 165960/381216 done
# 166080/381216 done
# 166200/381216 done
# 166320/381216 done
# 166440/381216 done
# 166560/381216 done
# 166680/381216 done
# 166800/381216 done
# 166920/381216 done
# 167040/381216 done
# 167160/381216 done
# 167280/381216 done
# 167400/381216 done
# 167520/381216 done
# 167640/381216 done
# 167760/381216 done
# 167880/381216 done
# 168000/381216 done
# 168120/381216 done
# 168240/381216 done
# 168360/381216 done
# 168480/381216 done
# 168600/381216 done
# 168720/381216 done
# 168840/381216 done
# 168960/381216 done
# 169080/381216 done
# 169200/381216 done
# 169320/381216 done
# 169440/381216 done
# 169560/381216 done
# 169680/381216 done
# 169800/381216 done
# 169920/381216 done
# 170040/381216 done
# 170160/381216 done
# 170280/381216 done
# 170400/381216 done
# 170520/381216 done
# 170640/381216 done
# 170760/381216 done
# 170880/381216 done
# 171000/381216 done
# 171120/381216 done
# 171240/381216 done
# 171360/381216 done
# 171480/381216 done
# 171600/381216 done
# 171720/381216 done
# 171840/381216 done
# 171960/381216 done
# 172080/381216 done
# 172200/381216 done
# 172320/381216 done
# 172440/381216 done
# 172560/381216 done
# 172680/381216 done
# 172800/381216 done
# 172920/381216 done
# 173040/381216 done
# 173160/381216 done
# 173280/381216 done
# 173400/381216 done
# 173520/381216 done
# 173640/381216 done
# 173760/381216 done
# 173880/381216 done
# 174000/381216 done
# 174120/381216 done
# 174240/381216 done
# 174360/381216 done
# 174480/381216 done
# 174600/381216 done
# 174720/381216 done
# 174840/381216 done
# 174960/381216 done
# 175080/381216 done
# 175200/381216 done
# 175320/381216 done
# 175440/381216 done
# 175560/381216 done
# 175680/381216 done
# 175800/381216 done
# 175920/381216 done
# 176040/381216 done
# 176160/381216 done
# 176280/381216 done
# 176400/381216 done
# 176520/381216 done
# 176640/381216 done
# 176760/381216 done
# 176880/381216 done
# 177000/381216 done
# 177120/381216 done
# 177240/381216 done
# 177360/381216 done
# 177480/381216 done
# 177600/381216 done
# 177720/381216 done
# 177840/381216 done
# 177960/381216 done
# 178080/381216 done
# 178200/381216 done
# 178320/381216 done
# 178440/381216 done
# 178560/381216 done
# 178680/381216 done
# 178800/381216 done
# 178920/381216 done
# Error: Failed to retrieve data. Status code 429
# 178920 - 179040 to redo
# 179040/381216 done
# 179160/381216 done
# 179280/381216 done
# Error: Failed to retrieve data. Status code 429
# 179280 - 179400 to redo
# 179400/381216 done
# 179520/381216 done
# Error: Failed to retrieve data. Status code 429
# 179520 - 179640 to redo
# 179640/381216 done
# Error: Failed to retrieve data. Status code 429
# 179640 - 179760 to redo
# 179760/381216 done
# 179880/381216 done
# Error: Failed to retrieve data. Status code 429
# 179880 - 180000 to redo
# 180000/381216 done
# Error: Failed to retrieve data. Status code 429
# 180000 - 180120 to redo
# 180120/381216 done
# Error: Failed to retrieve data. Status code 429
# 180120 - 180240 to redo
# 180240/381216 done
# Error: Failed to retrieve data. Status code 429
# 180240 - 180360 to redo
# 180360/381216 done
# Error: Failed to retrieve data. Status code 429
# 180360 - 180480 to redo
# 180480/381216 done
# Error: Failed to retrieve data. Status code 429
# 180480 - 180600 to redo
# 180600/381216 done
# 180720/381216 done
# Error: Failed to retrieve data. Status code 429
# 180720 - 180840 to redo
# 180840/381216 done
# Error: Failed to retrieve data. Status code 429
# 180840 - 180960 to redo
# 180960/381216 done
# 181080/381216 done
# 181200/381216 done
# 181320/381216 done
# 181440/381216 done
# Error: Failed to retrieve data. Status code 429
# 181440 - 181560 to redo
# 181560/381216 done
# 181680/381216 done
# Error: Failed to retrieve data. Status code 429
# 181680 - 181800 to redo
# 181800/381216 done
# 181920/381216 done
# 182040/381216 done
# 182160/381216 done
# 182280/381216 done
# 182400/381216 done
# 182520/381216 done
# 182640/381216 done
# 182760/381216 done
# 182880/381216 done
# 183000/381216 done
# 183120/381216 done
# 183240/381216 done
# 183360/381216 done
# 183480/381216 done
# 183600/381216 done
# 183720/381216 done
# 183840/381216 done
# 183960/381216 done
# 184080/381216 done
# 184200/381216 done
# 184320/381216 done
# 184440/381216 done
# 184560/381216 done
# 184680/381216 done
# 184800/381216 done
# 184920/381216 done
# 185040/381216 done
# 185160/381216 done
# 185280/381216 done
# 185400/381216 done
# 185520/381216 done
# 185640/381216 done
# 185760/381216 done
# 185880/381216 done
# 186000/381216 done
# 186120/381216 done
# 186240/381216 done
# Error: Failed to retrieve data. Status code 429
# 186240 - 186360 to redo
# 186360/381216 done
# 186480/381216 done
# 186600/381216 done
# 186720/381216 done
# 186840/381216 done
# 186960/381216 done
# 187080/381216 done
# Error: Failed to retrieve data. Status code 429
# 187080 - 187200 to redo
# 187200/381216 done
# 187320/381216 done
# 187440/381216 done
# Error: Failed to retrieve data. Status code 429
# 187440 - 187560 to redo
# 187560/381216 done
# 187680/381216 done
# Error: Failed to retrieve data. Status code 429
# 187680 - 187800 to redo
# 187800/381216 done
# 187920/381216 done
# 188040/381216 done
# 188160/381216 done
# Error: Failed to retrieve data. Status code 429
# 188160 - 188280 to redo
# 188280/381216 done
# Error: Failed to retrieve data. Status code 429
# 188280 - 188400 to redo
# 188400/381216 done
# 188520/381216 done
# 188640/381216 done
# Error: Failed to retrieve data. Status code 429
# 188640 - 188760 to redo
# 188760/381216 done
# 188880/381216 done
# 189000/381216 done
# 189120/381216 done
# Error: Failed to retrieve data. Status code 429
# 189120 - 189240 to redo
# 189240/381216 done
# Error: Failed to retrieve data. Status code 429
# 189240 - 189360 to redo
# 189360/381216 done
# Error: Failed to retrieve data. Status code 429
# 189360 - 189480 to redo
# 189480/381216 done
# 189600/381216 done
# 189720/381216 done
# Error: Failed to retrieve data. Status code 429
# 189720 - 189840 to redo
# 189840/381216 done
# Error: Failed to retrieve data. Status code 429
# 189840 - 189960 to redo
# 189960/381216 done
# Error: Failed to retrieve data. Status code 429
# 189960 - 190080 to redo
# 190080/381216 done
# 190200/381216 done
# Error: Failed to retrieve data. Status code 429
# 190200 - 190320 to redo
# 190320/381216 done
# Error: Failed to retrieve data. Status code 429
# 190320 - 190440 to redo
# 190440/381216 done
# 190560/381216 done
# Error: Failed to retrieve data. Status code 429
# 190560 - 190680 to redo
# Error: Failed to retrieve data. Status code 429
# 190560 - 190680 to redo
# 190680/381216 done
# Error: Failed to retrieve data. Status code 429
# 190680 - 190800 to redo
# 190800/381216 done
# Error: Failed to retrieve data. Status code 429
# 190800 - 190920 to redo
# 190920/381216 done
# Error: Failed to retrieve data. Status code 429
# 190920 - 191040 to redo
# 191040/381216 done
# Error: Failed to retrieve data. Status code 429
# 191040 - 191160 to redo
# 191160/381216 done
# Error: Failed to retrieve data. Status code 429
# 191160 - 191280 to redo
# 191280/381216 done
# 191400/381216 done
# Error: Failed to retrieve data. Status code 429
# 191400 - 191520 to redo
# 191520/381216 done
# Error: Failed to retrieve data. Status code 429
# 191520 - 191640 to redo
# 191640/381216 done
# Error: Failed to retrieve data. Status code 429
# 191640 - 191760 to redo
# 191760/381216 done
# 191880/381216 done
# Error: Failed to retrieve data. Status code 429
# 191880 - 192000 to redo
# 192000/381216 done
# 192120/381216 done
# 192240/381216 done
# Error: Failed to retrieve data. Status code 429
# 192240 - 192360 to redo
# 192360/381216 done
# 192480/381216 done
# 192600/381216 done
# 192720/381216 done
# 192840/381216 done
# 192960/381216 done
# 193080/381216 done
# 193200/381216 done
# 193320/381216 done
# 193440/381216 done
# 193560/381216 done
# 193680/381216 done
# 193800/381216 done
# 193920/381216 done
# 194040/381216 done
# 194160/381216 done
# 194280/381216 done
# 194400/381216 done
# 194520/381216 done
# 194640/381216 done
# 194760/381216 done
# 194880/381216 done
# 195000/381216 done
# 195120/381216 done
# 195240/381216 done
# 195360/381216 done
# 195480/381216 done
# 195600/381216 done
# 195720/381216 done
# 195840/381216 done
# 195960/381216 done
# 196080/381216 done
# 196200/381216 done
# 196320/381216 done
# 196440/381216 done
# 196560/381216 done
# 196680/381216 done
# 196800/381216 done
# 196920/381216 done
# 197040/381216 done
# 197160/381216 done
# Error: Failed to retrieve data. Status code 429
# 197160 - 197280 to redo
# 197280/381216 done
# 197400/381216 done
# Error: Failed to retrieve data. Status code 429
# 197400 - 197520 to redo
# 197520/381216 done
# Error: Failed to retrieve data. Status code 429
# 197520 - 197640 to redo
# 197640/381216 done
# Error: Failed to retrieve data. Status code 429
# 197640 - 197760 to redo
# 197760/381216 done
# Error: Failed to retrieve data. Status code 429
# 197760 - 197880 to redo
# 197880/381216 done
# Error: Failed to retrieve data. Status code 429
# 197880 - 198000 to redo
# 198000/381216 done
# Error: Failed to retrieve data. Status code 429
# 198000 - 198120 to redo
# 198120/381216 done
# 198240/381216 done
# Error: Failed to retrieve data. Status code 429
# 198240 - 198360 to redo
# 198360/381216 done
# 198480/381216 done
# 198600/381216 done
# 198720/381216 done
# Error: Failed to retrieve data. Status code 429
# 198720 - 198840 to redo
# 198840/381216 done
# Error: Failed to retrieve data. Status code 429
# 198840 - 198960 to redo
# 198960/381216 done
# 199080/381216 done
# 199200/381216 done
# Error: Failed to retrieve data. Status code 429
# 199200 - 199320 to redo
# 199320/381216 done
# Error: Failed to retrieve data. Status code 429
# 199320 - 199440 to redo
# 199440/381216 done
# Error: Failed to retrieve data. Status code 429
# 199440 - 199560 to redo
# 199560/381216 done
# 199680/381216 done
# 199800/381216 done
# 199920/381216 done
# 200040/381216 done
# 200160/381216 done
# 200280/381216 done
# 200400/381216 done
# 200520/381216 done
# 200640/381216 done
# 200760/381216 done
# 200880/381216 done
# 201000/381216 done
# 201120/381216 done
# 201240/381216 done
# 201360/381216 done
# 201480/381216 done
# 201600/381216 done
# 201720/381216 done
# 201840/381216 done
# 201960/381216 done
# 202080/381216 done
# 202200/381216 done
# 202320/381216 done
# 202440/381216 done
# 202560/381216 done
# 202680/381216 done
# 202800/381216 done
# 202920/381216 done
# 203040/381216 done
# 203160/381216 done
# 203280/381216 done
# 203400/381216 done
# 203520/381216 done
# 203640/381216 done
# 203760/381216 done
# 203880/381216 done
# 204000/381216 done
# 204120/381216 done
# 204240/381216 done
# 204360/381216 done
# 204480/381216 done
# 204600/381216 done
# 204720/381216 done
# 204840/381216 done
# 204960/381216 done
# 205080/381216 done
# 205200/381216 done
# 205320/381216 done
# 205440/381216 done
# 205560/381216 done
# 205680/381216 done
# 205800/381216 done
# 205920/381216 done
# 206040/381216 done
# 206160/381216 done
# 206280/381216 done
# 206400/381216 done
# 206520/381216 done
# 206640/381216 done
# 206760/381216 done
# Error: Failed to retrieve data. Status code 429
# 206760 - 206880 to redo
# 206880/381216 done
# Error: Failed to retrieve data. Status code 429
# 206880 - 207000 to redo
# 207000/381216 done
# Error: Failed to retrieve data. Status code 429
# 207000 - 207120 to redo
# 207120/381216 done
# 207240/381216 done
# Error: Failed to retrieve data. Status code 429
# 207240 - 207360 to redo
# 207360/381216 done
# 207480/381216 done
# Error: Failed to retrieve data. Status code 429
# 207480 - 207600 to redo
# 207600/381216 done
# 207720/381216 done
# 207840/381216 done
# Error: Failed to retrieve data. Status code 429
# 207840 - 207960 to redo
# 207960/381216 done
# 208080/381216 done
# 208200/381216 done
# Error: Failed to retrieve data. Status code 429
# 208200 - 208320 to redo
# 208320/381216 done
# Error: Failed to retrieve data. Status code 429
# 208320 - 208440 to redo
# 208440/381216 done
# Error: Failed to retrieve data. Status code 429
# 208440 - 208560 to redo
# 208560/381216 done
# Error: Failed to retrieve data. Status code 429
# 208560 - 208680 to redo
# 208680/381216 done
# 208800/381216 done
# 208920/381216 done
# 209040/381216 done
# 209160/381216 done
# Error: Failed to retrieve data. Status code 429
# 209160 - 209280 to redo
# Error: Failed to retrieve data. Status code 429
# 209160 - 209280 to redo
# 209280/381216 done
# Error: Failed to retrieve data. Status code 429
# 209280 - 209400 to redo
# 209400/381216 done
# Error: Failed to retrieve data. Status code 429
# 209400 - 209520 to redo
# 209520/381216 done
# 209640/381216 done
# Error: Failed to retrieve data. Status code 429
# 209640 - 209760 to redo
# 209760/381216 done
# 209880/381216 done
# 210000/381216 done
# 210120/381216 done
# 210240/381216 done
# 210360/381216 done
# 210480/381216 done
# 210600/381216 done
# 210720/381216 done
# 210840/381216 done
# 210960/381216 done
# 211080/381216 done
# 211200/381216 done
# 211320/381216 done
# Error: Failed to retrieve data. Status code 429
# 211320 - 211440 to redo
# 211440/381216 done
# 211560/381216 done
# 211680/381216 done
# 211800/381216 done
# 211920/381216 done
# 212040/381216 done
# 212160/381216 done
# 212280/381216 done
# 212400/381216 done
# 212520/381216 done
# 212640/381216 done
# 212760/381216 done
# 212880/381216 done
# 213000/381216 done
# 213120/381216 done
# 213240/381216 done
# 213360/381216 done
# 213480/381216 done
# 213600/381216 done
# 213720/381216 done
# 213840/381216 done
# 213960/381216 done
# 214080/381216 done
# 214200/381216 done
# 214320/381216 done
# 214440/381216 done
# 214560/381216 done
# 214680/381216 done
# 214800/381216 done
# 214920/381216 done
# 215040/381216 done
# 215160/381216 done
# 215280/381216 done
# 215400/381216 done
# 215520/381216 done
# 215640/381216 done
# 215760/381216 done
# 215880/381216 done
# 216000/381216 done
# 216120/381216 done
# 216240/381216 done
# 216360/381216 done
# 216480/381216 done
# 216600/381216 done
# 216720/381216 done
# 216840/381216 done
# 216960/381216 done
# 217080/381216 done
# 217200/381216 done
# 217320/381216 done
# 217440/381216 done
# 217560/381216 done
# 217680/381216 done
# 217800/381216 done
# 217920/381216 done
# 218040/381216 done
# 218160/381216 done
# 218280/381216 done
# 218400/381216 done
# 218520/381216 done
# 218640/381216 done
# 218760/381216 done
# Error: Failed to retrieve data. Status code 429
# 218760 - 218880 to redo
# 218880/381216 done
# 219000/381216 done
# Error: Failed to retrieve data. Status code 429
# 219000 - 219120 to redo
# 219120/381216 done
# 219240/381216 done
# 219360/381216 done
# 219480/381216 done
# 219600/381216 done
# 219720/381216 done
# 219840/381216 done
# Error: Failed to retrieve data. Status code 429
# 219840 - 219960 to redo
# 219960/381216 done
# 220080/381216 done
# 220200/381216 done
# Error: Failed to retrieve data. Status code 429
# 220200 - 220320 to redo
# 220320/381216 done
# 220440/381216 done
# 220560/381216 done
# 220680/381216 done
# Error: Failed to retrieve data. Status code 429
# 220680 - 220800 to redo
# 220800/381216 done
# Error: Failed to retrieve data. Status code 429
# 220800 - 220920 to redo
# 220920/381216 done
# 221040/381216 done
# 221160/381216 done
# Error: Failed to retrieve data. Status code 429
# 221160 - 221280 to redo
# 221280/381216 done
# 221400/381216 done
# 221520/381216 done
# Error: Failed to retrieve data. Status code 429
# 221520 - 221640 to redo
# 221640/381216 done
# Error: Failed to retrieve data. Status code 429
# 221640 - 221760 to redo
# 221760/381216 done
# Error: Failed to retrieve data. Status code 429
# 221760 - 221880 to redo
# 221880/381216 done
# Error: Failed to retrieve data. Status code 429
# 221880 - 222000 to redo
# 222000/381216 done
# 222120/381216 done
# 222240/381216 done
# 222360/381216 done
# 222480/381216 done
# 222600/381216 done
# 222720/381216 done
# 222840/381216 done
# 222960/381216 done
# 223080/381216 done
# 223200/381216 done
# 223320/381216 done
# 223440/381216 done
# 223560/381216 done
# 223680/381216 done
# 223800/381216 done
# 223920/381216 done
# 224040/381216 done
# 224160/381216 done
# 224280/381216 done
# 224400/381216 done
# 224520/381216 done
# 224640/381216 done
# 224760/381216 done
# 224880/381216 done
# 225000/381216 done
# 225120/381216 done
# 225240/381216 done
# 225360/381216 done
# 225480/381216 done
# 225600/381216 done
# 225720/381216 done
# 225840/381216 done
# 225960/381216 done
# 226080/381216 done
# 226200/381216 done
# Error: Failed to retrieve data. Status code 429
# 226200 - 226320 to redo
# 226320/381216 done
# 226440/381216 done
# Error: Failed to retrieve data. Status code 429
# 226440 - 226560 to redo
# 226560/381216 done
# Error: Failed to retrieve data. Status code 429
# 226560 - 226680 to redo
# 226680/381216 done
# 226800/381216 done
# 226920/381216 done
# Error: Failed to retrieve data. Status code 429
# 226920 - 227040 to redo
# 227040/381216 done
# 227160/381216 done
# 227280/381216 done
# 227400/381216 done
# 227520/381216 done
# Error: Failed to retrieve data. Status code 429
# 227520 - 227640 to redo
# 227640/381216 done
# 227760/381216 done
# 227880/381216 done
# 228000/381216 done
# 228120/381216 done
# 228240/381216 done
# 228360/381216 done
# 228480/381216 done
# 228600/381216 done
# 228720/381216 done
# 228840/381216 done
# 228960/381216 done
# 229080/381216 done
# 229200/381216 done
# 229320/381216 done
# 229440/381216 done
# 229560/381216 done
# 229680/381216 done
# 229800/381216 done
# 229920/381216 done
# 230040/381216 done
# 230160/381216 done
# 230280/381216 done
# 230400/381216 done
# Error: Failed to retrieve data. Status code 429
# 230400 - 230520 to redo
# 230520/381216 done
# Error: Failed to retrieve data. Status code 429
# 230520 - 230640 to redo
# 230640/381216 done
# 230760/381216 done
# 230880/381216 done
# 231000/381216 done
# 231120/381216 done
# 231240/381216 done
# 231360/381216 done
# 231480/381216 done
# 231600/381216 done
# 231720/381216 done
# 231840/381216 done
# 231960/381216 done
# 232080/381216 done
# 232200/381216 done
# 232320/381216 done
# 232440/381216 done
# 232560/381216 done
# 232680/381216 done
# 232800/381216 done
# 232920/381216 done
# 233040/381216 done
# 233160/381216 done
# 233280/381216 done
# 233400/381216 done
# 233520/381216 done
# 233640/381216 done
# 233760/381216 done
# 233880/381216 done
# 234000/381216 done
# 234120/381216 done
# 234240/381216 done
# 234360/381216 done
# 234480/381216 done
# 234600/381216 done
# 234720/381216 done
# 234840/381216 done
# 234960/381216 done
# 235080/381216 done
# 235200/381216 done
# 235320/381216 done
# 235440/381216 done
# 235560/381216 done
# 235680/381216 done
# 235800/381216 done
# 235920/381216 done
# 236040/381216 done
# 236160/381216 done
# 236280/381216 done
# 236400/381216 done
# 236520/381216 done
# 236640/381216 done
# 236760/381216 done
# 236880/381216 done
# 237000/381216 done
# 237120/381216 done
# 237240/381216 done
# 237360/381216 done
# 237480/381216 done
# 237600/381216 done
# 237720/381216 done
# 237840/381216 done
# 237960/381216 done
# 238080/381216 done
# 238200/381216 done
# 238320/381216 done
# 238440/381216 done
# 238560/381216 done
# 238680/381216 done
# 238800/381216 done
# 238920/381216 done
# 239040/381216 done
# 239160/381216 done
# 239280/381216 done
# 239400/381216 done
# 239520/381216 done
# 239640/381216 done
# 239760/381216 done
# 239880/381216 done
# 240000/381216 done
# 240120/381216 done
# 240240/381216 done
# 240360/381216 done
# 240480/381216 done
# 240600/381216 done
# 240720/381216 done
# 240840/381216 done
# 240960/381216 done
# 241080/381216 done
# 241200/381216 done
# 241320/381216 done
# 241440/381216 done
# 241560/381216 done
# 241680/381216 done
# 241800/381216 done
# 241920/381216 done
# 242040/381216 done
# 242160/381216 done
# 242280/381216 done
# 242400/381216 done
# 242520/381216 done
# 242640/381216 done
# 242760/381216 done
# 242880/381216 done
# 243000/381216 done
# 243120/381216 done
# 243240/381216 done
# 243360/381216 done
# 243480/381216 done
# 243600/381216 done
# 243720/381216 done
# 243840/381216 done
# 243960/381216 done
# 244080/381216 done
# 244200/381216 done
# 244320/381216 done
# 244440/381216 done
# 244560/381216 done
# 244680/381216 done
# 244800/381216 done
# 244920/381216 done
# 245040/381216 done
# 245160/381216 done
# 245280/381216 done
# 245400/381216 done
# 245520/381216 done
# 245640/381216 done
# 245760/381216 done
# 245880/381216 done
# 246000/381216 done
# 246120/381216 done
# 246240/381216 done
# 246360/381216 done
# 246480/381216 done
# 246600/381216 done
# 246720/381216 done
# 246840/381216 done
# 246960/381216 done
# 247080/381216 done
# 247200/381216 done
# 247320/381216 done
# 247440/381216 done
# 247560/381216 done
# 247680/381216 done
# 247800/381216 done
# Error: Failed to retrieve data. Status code 429
# 247800 - 247920 to redo
# 247920/381216 done
# Error: Failed to retrieve data. Status code 429
# 247920 - 248040 to redo
# 248040/381216 done
# Error: Failed to retrieve data. Status code 429
# 248040 - 248160 to redo
# 248160/381216 done
# Error: Failed to retrieve data. Status code 429
# 248160 - 248280 to redo
# 248280/381216 done
# Error: Failed to retrieve data. Status code 429
# 248280 - 248400 to redo
# 248400/381216 done
# 248520/381216 done
# 248640/381216 done
# Error: Failed to retrieve data. Status code 429
# 248640 - 248760 to redo
# 248760/381216 done
# 248880/381216 done
# Error: Failed to retrieve data. Status code 429
# 248880 - 249000 to redo
# 249000/381216 done
# 249120/381216 done
# Error: Failed to retrieve data. Status code 429
# 249120 - 249240 to redo
# 249240/381216 done
# 249360/381216 done
# Error: Failed to retrieve data. Status code 429
# 249360 - 249480 to redo
# 249480/381216 done
# 249600/381216 done
# 249720/381216 done
# Error: Failed to retrieve data. Status code 429
# 249720 - 249840 to redo
# 249840/381216 done
# Error: Failed to retrieve data. Status code 429
# 249840 - 249960 to redo
# 249960/381216 done
# Error: Failed to retrieve data. Status code 429
# 249960 - 250080 to redo
# 250080/381216 done
# 250200/381216 done
# Error: Failed to retrieve data. Status code 429
# 250200 - 250320 to redo
# 250320/381216 done
# 250440/381216 done
# Error: Failed to retrieve data. Status code 429
# 250440 - 250560 to redo
# 250560/381216 done
# Error: Failed to retrieve data. Status code 429
# 250560 - 250680 to redo
# 250680/381216 done
# Error: Failed to retrieve data. Status code 429
# 250680 - 250800 to redo
# 250800/381216 done
# Error: Failed to retrieve data. Status code 429
# 250800 - 250920 to redo
# 250920/381216 done
# Error: Failed to retrieve data. Status code 429
# 250920 - 251040 to redo
# 251040/381216 done
# 251160/381216 done
# Error: Failed to retrieve data. Status code 429
# 251160 - 251280 to redo
# 251280/381216 done
# Error: Failed to retrieve data. Status code 429
# 251280 - 251400 to redo
# 251400/381216 done
# Error: Failed to retrieve data. Status code 429
# 251400 - 251520 to redo
# 251520/381216 done
# Error: Failed to retrieve data. Status code 429
# 251520 - 251640 to redo
# 251640/381216 done
# Error: Failed to retrieve data. Status code 429
# 251640 - 251760 to redo
# 251760/381216 done
# Error: Failed to retrieve data. Status code 429
# 251760 - 251880 to redo
# 251880/381216 done
# 252000/381216 done
# Error: Failed to retrieve data. Status code 429
# 252000 - 252120 to redo
# 252120/381216 done
# Error: Failed to retrieve data. Status code 429
# 252120 - 252240 to redo
# 252240/381216 done
# 252360/381216 done
# Error: Failed to retrieve data. Status code 429
# 252360 - 252480 to redo
# 252480/381216 done
# Error: Failed to retrieve data. Status code 429
# 252480 - 252600 to redo
# 252600/381216 done
# ...
# 333120/381216 done
# 333240/381216 done
# 333360/381216 done
# 333480/381216 done
# 333600/381216 done
# 333720/381216 done
# 333840/381216 done
# 333960/381216 done
# Error: Failed to retrieve data. Status code 429
# 333960 - 334080 to redo
# 334080/381216 done
# 334200/381216 done
# 334320/381216 done
# Error: Failed to retrieve data. Status code 429
# 334320 - 334440 to redo
# 334440/381216 done
# 334560/381216 done
# 334680/381216 done
# Error: Failed to retrieve data. Status code 429
# 334680 - 334800 to redo
# 334800/381216 done
# 334920/381216 done
# 335040/381216 done
# 335160/381216 done
# Error: Failed to retrieve data. Status code 429
# 335160 - 335280 to redo
# 335280/381216 done
# Error: Failed to retrieve data. Status code 429
# 335280 - 335400 to redo
# 335400/381216 done
# 335520/381216 done
# Error: Failed to retrieve data. Status code 429
# 335520 - 335640 to redo
# 335640/381216 done
# Error: Failed to retrieve data. Status code 429
# 335640 - 335760 to redo
# 335760/381216 done
# Error: Failed to retrieve data. Status code 429
# 335760 - 335880 to redo
# 335880/381216 done
# 336000/381216 done
# 336120/381216 done
# 336240/381216 done
# 336360/381216 done
# 336480/381216 done
# Error: Failed to retrieve data. Status code 429
# 336480 - 336600 to redo
# 336600/381216 done
# 336720/381216 done
# 336840/381216 done
# 336960/381216 done
# Error: Failed to retrieve data. Status code 429
# 336960 - 337080 to redo
# 337080/381216 done
# 337200/381216 done
# Error: Failed to retrieve data. Status code 429
# 337200 - 337320 to redo
# 337320/381216 done
# Error: Failed to retrieve data. Status code 429
# 337320 - 337440 to redo
# 337440/381216 done
# Error: Failed to retrieve data. Status code 429
# 337440 - 337560 to redo
# 337560/381216 done
# Error: Failed to retrieve data. Status code 429
# 337560 - 337680 to redo
# 337680/381216 done
# 337800/381216 done
# Error: Failed to retrieve data. Status code 429
# 337800 - 337920 to redo
# 337920/381216 done
# 338040/381216 done
# Error: Failed to retrieve data. Status code 429
# 338040 - 338160 to redo
# 338160/381216 done
# 338280/381216 done
# 338400/381216 done
# 338520/381216 done
# 338640/381216 done
# Error: Failed to retrieve data. Status code 429
# 338640 - 338760 to redo
# 338760/381216 done
# 338880/381216 done
# Error: Failed to retrieve data. Status code 429
# 338880 - 339000 to redo
# 339000/381216 done
# Error: Failed to retrieve data. Status code 429
# 339000 - 339120 to redo
# 339120/381216 done
# 339240/381216 done
# 339360/381216 done
# 339480/381216 done
# 339600/381216 done
# 339720/381216 done
# 339840/381216 done
# 339960/381216 done
# 340080/381216 done
# 340200/381216 done
# 340320/381216 done
# 340440/381216 done
# 340560/381216 done
# 340680/381216 done
# 340800/381216 done
# 340920/381216 done
# 341040/381216 done
# 341160/381216 done
# 341280/381216 done
# 341400/381216 done
# 341520/381216 done
# 341640/381216 done
# 341760/381216 done
# 341880/381216 done
# 342000/381216 done
# 342120/381216 done
# 342240/381216 done
# 342360/381216 done
# 342480/381216 done
# 342600/381216 done
# 342720/381216 done
# 342840/381216 done
# 342960/381216 done
# 343080/381216 done
# 343200/381216 done
# 343320/381216 done
# 343440/381216 done
# 343560/381216 done
# 343680/381216 done
# 343800/381216 done
# 343920/381216 done
# 344040/381216 done
# 344160/381216 done
# 344280/381216 done
# 344400/381216 done
# 344520/381216 done
# 344640/381216 done
# 344760/381216 done
# 344880/381216 done
# 345000/381216 done
# 345120/381216 done
# 345240/381216 done
# 345360/381216 done
# 345480/381216 done
# 345600/381216 done
# 345720/381216 done
# 345840/381216 done
# 345960/381216 done
# 346080/381216 done
# 346200/381216 done
# 346320/381216 done
# 346440/381216 done
# 346560/381216 done
# 346680/381216 done
# 346800/381216 done
# 346920/381216 done
# 347040/381216 done
# 347160/381216 done
# 347280/381216 done
# 347400/381216 done
# 347520/381216 done
# 347640/381216 done
# 347760/381216 done
# 347880/381216 done
# 348000/381216 done
# 348120/381216 done
# 348240/381216 done
# 348360/381216 done
# 348480/381216 done
# 348600/381216 done
# 348720/381216 done
# 348840/381216 done
# 348960/381216 done
# 349080/381216 done
# 349200/381216 done
# 349320/381216 done
# 349440/381216 done
# 349560/381216 done
# 349680/381216 done
# 349800/381216 done
# 349920/381216 done
# 350040/381216 done
# 350160/381216 done
# 350280/381216 done
# 350400/381216 done
# 350520/381216 done
# 350640/381216 done
# 350760/381216 done
# 350880/381216 done
# 351000/381216 done
# 351120/381216 done
# 351240/381216 done
# 351360/381216 done
# 351480/381216 done
# 351600/381216 done
# 351720/381216 done
# 351840/381216 done
# 351960/381216 done
# 352080/381216 done
# 352200/381216 done
# 352320/381216 done
# 352440/381216 done
# 352560/381216 done
# 352680/381216 done
# 352800/381216 done
# 352920/381216 done
# Error: Failed to retrieve data. Status code 429
# 352920 - 353040 to redo
# 353040/381216 done
# 353160/381216 done
# 353280/381216 done
# Error: Failed to retrieve data. Status code 429
# 353280 - 353400 to redo
# 353400/381216 done
# 353520/381216 done
# 353640/381216 done
# 353760/381216 done
# 353880/381216 done
# 354000/381216 done
# 354120/381216 done
# 354240/381216 done
# 354360/381216 done
# 354480/381216 done
# 354600/381216 done
# 354720/381216 done
# 354840/381216 done
# 354960/381216 done
# 355080/381216 done
# 355200/381216 done
# 355320/381216 done
# 355440/381216 done
# 355560/381216 done
# 355680/381216 done
# 355800/381216 done
# 355920/381216 done
# 356040/381216 done
# 356160/381216 done
# 356280/381216 done
# 356400/381216 done
# 356520/381216 done
# 356640/381216 done
# 356760/381216 done
# 356880/381216 done
# 357000/381216 done
# 357120/381216 done
# 357240/381216 done
# 357360/381216 done
# 357480/381216 done
# 357600/381216 done
# 357720/381216 done
# 357840/381216 done
# 357960/381216 done
# 358080/381216 done
# 358200/381216 done
# 358320/381216 done
# 358440/381216 done
# 358560/381216 done
# 358680/381216 done
# 358800/381216 done
# 358920/381216 done
# 359040/381216 done
# 359160/381216 done
# 359280/381216 done
# 359400/381216 done
# 359520/381216 done
# 359640/381216 done
# 359760/381216 done
# 359880/381216 done
# 360000/381216 done
# 360120/381216 done
# 360240/381216 done
# 360360/381216 done
# 360480/381216 done
# 360600/381216 done
# 360720/381216 done
# 360840/381216 done
# 360960/381216 done
# 361080/381216 done
# 361200/381216 done
# 361320/381216 done
# 361440/381216 done
# 361560/381216 done
# 361680/381216 done
# 361800/381216 done
# 361920/381216 done
# 362040/381216 done
# 362160/381216 done
# 362280/381216 done
# 362400/381216 done
# 362520/381216 done
# 362640/381216 done
# 362760/381216 done
# 362880/381216 done
# 363000/381216 done
# 363120/381216 done
# 363240/381216 done
# 363360/381216 done
# 363480/381216 done
# 363600/381216 done
# 363720/381216 done
# 363840/381216 done
# 363960/381216 done
# 364080/381216 done
# 364200/381216 done
# 364320/381216 done
# Error: Failed to retrieve data. Status code 429
# 364320 - 364440 to redo
# Error: Failed to retrieve data. Status code 429
# 364320 - 364440 to redo
# 364440/381216 done
# Error: Failed to retrieve data. Status code 429
# 364440 - 364560 to redo
# Error: Failed to retrieve data. Status code 429
# 364440 - 364560 to redo
# 364560/381216 done
# Error: Failed to retrieve data. Status code 429
# 364560 - 364680 to redo
# Error: Failed to retrieve data. Status code 429
# 364560 - 364680 to redo
# 364680/381216 done
# Error: Failed to retrieve data. Status code 429
# 364680 - 364800 to redo
# 364800/381216 done
# Error: Failed to retrieve data. Status code 429
# 364800 - 364920 to redo
# 364920/381216 done
# Error: Failed to retrieve data. Status code 429
# 364920 - 365040 to redo
# Error: Failed to retrieve data. Status code 429
# 364920 - 365040 to redo
# 365040/381216 done
# Error: Failed to retrieve data. Status code 429
# 365040 - 365160 to redo
# Error: Failed to retrieve data. Status code 429
# 365040 - 365160 to redo
# 365160/381216 done
# 365280/381216 done
# 365400/381216 done
# Error: Failed to retrieve data. Status code 429
# 365400 - 365520 to redo
# Error: Failed to retrieve data. Status code 429
# 365400 - 365520 to redo
# 365520/381216 done
# Error: Failed to retrieve data. Status code 429
# 365520 - 365640 to redo
# 365640/381216 done
# Error: Failed to retrieve data. Status code 429
# 365640 - 365760 to redo
# 365760/381216 done
# 365880/381216 done
# 366000/381216 done
# Error: Failed to retrieve data. Status code 429
# 366000 - 366120 to redo
# 366120/381216 done
# 366240/381216 done
# Error: Failed to retrieve data. Status code 429
# 366240 - 366360 to redo
# 366360/381216 done
# 366480/381216 done
# Error: Failed to retrieve data. Status code 429
# 366480 - 366600 to redo
# 366600/381216 done
# 366720/381216 done
# Error: Failed to retrieve data. Status code 429
# 366720 - 366840 to redo
# Error: Failed to retrieve data. Status code 429
# 366720 - 366840 to redo
# 366840/381216 done
# Error: Failed to retrieve data. Status code 429
# 366840 - 366960 to redo
# Error: Failed to retrieve data. Status code 429
# 366840 - 366960 to redo
# 366960/381216 done
# Error: Failed to retrieve data. Status code 429
# 366960 - 367080 to redo
# 367080/381216 done
# Error: Failed to retrieve data. Status code 429
# 367080 - 367200 to redo
# 367200/381216 done
# Error: Failed to retrieve data. Status code 429
# 367200 - 367320 to redo
# Error: Failed to retrieve data. Status code 429
# 367200 - 367320 to redo
# 367320/381216 done
# 367440/381216 done
# 367560/381216 done
# Error: Failed to retrieve data. Status code 429
# 367560 - 367680 to redo
# Error: Failed to retrieve data. Status code 429
# 367560 - 367680 to redo
# 367680/381216 done
# 367800/381216 done
# 367920/381216 done
# Error: Failed to retrieve data. Status code 429
# 367920 - 368040 to redo
# 368040/381216 done
# Error: Failed to retrieve data. Status code 429
# 368040 - 368160 to redo
# Error: Failed to retrieve data. Status code 429
# 368040 - 368160 to redo
# 368160/381216 done
# Error: Failed to retrieve data. Status code 429
# 368160 - 368280 to redo
# Error: Failed to retrieve data. Status code 429
# 368160 - 368280 to redo
# 368280/381216 done
# Error: Failed to retrieve data. Status code 429
# 368280 - 368400 to redo
# Error: Failed to retrieve data. Status code 429
# 368280 - 368400 to redo
# 368400/381216 done
# Error: Failed to retrieve data. Status code 429
# 368400 - 368520 to redo
# Error: Failed to retrieve data. Status code 429
# 368400 - 368520 to redo
# 368520/381216 done
# Error: Failed to retrieve data. Status code 429
# 368520 - 368640 to redo
# Error: Failed to retrieve data. Status code 429
# 368520 - 368640 to redo
# 368640/381216 done
# Error: Failed to retrieve data. Status code 429
# 368640 - 368760 to redo
# Error: Failed to retrieve data. Status code 429
# 368640 - 368760 to redo
# 368760/381216 done
# Error: Failed to retrieve data. Status code 429
# 368760 - 368880 to redo
# Error: Failed to retrieve data. Status code 429
# 368760 - 368880 to redo
# 368880/381216 done
# Error: Failed to retrieve data. Status code 429
# 368880 - 369000 to redo
# 369000/381216 done
# Error: Failed to retrieve data. Status code 429
# 369000 - 369120 to redo
# Error: Failed to retrieve data. Status code 429
# 369000 - 369120 to redo
# 369120/381216 done
# Error: Failed to retrieve data. Status code 429
# 369120 - 369240 to redo
# 369240/381216 done
# 369360/381216 done
# 369480/381216 done
# 369600/381216 done
# 369720/381216 done
# 369840/381216 done
# 369960/381216 done
# 370080/381216 done
# 370200/381216 done
# 370320/381216 done
# 370440/381216 done
# Error: Failed to retrieve data. Status code 429
# 370440 - 370560 to redo
# 370560/381216 done
# Error: Failed to retrieve data. Status code 429
# 370560 - 370680 to redo
# 370680/381216 done
# 370800/381216 done
# Error: Failed to retrieve data. Status code 429
# 370800 - 370920 to redo
# 370920/381216 done
# Error: Failed to retrieve data. Status code 429
# 370920 - 371040 to redo
# 371040/381216 done
# Error: Failed to retrieve data. Status code 429
# 371040 - 371160 to redo
# 371160/381216 done
# Error: Failed to retrieve data. Status code 429
# 371160 - 371280 to redo
# 371280/381216 done
# Error: Failed to retrieve data. Status code 429
# 371280 - 371400 to redo
# 371400/381216 done
# 371520/381216 done
# 371640/381216 done
# 371760/381216 done
# 371880/381216 done
# 372000/381216 done
# 372120/381216 done
# 372240/381216 done
# 372360/381216 done
# Error: Failed to retrieve data. Status code 429
# 372360 - 372480 to redo
# 372480/381216 done
# Error: Failed to retrieve data. Status code 429
# 372480 - 372600 to redo
# 372600/381216 done
# Error: Failed to retrieve data. Status code 429
# 372600 - 372720 to redo
# 372720/381216 done
# Error: Failed to retrieve data. Status code 429
# 372720 - 372840 to redo
# 372840/381216 done
# Error: Failed to retrieve data. Status code 429
# 372840 - 372960 to redo
# 372960/381216 done
# Error: Failed to retrieve data. Status code 429
# 372960 - 373080 to redo
# 373080/381216 done
# 373200/381216 done
# 373320/381216 done
# 373440/381216 done
# 373560/381216 done
# 373680/381216 done
# 373800/381216 done
# 373920/381216 done
# Error: Failed to retrieve data. Status code 429
# 373920 - 374040 to redo
# 374040/381216 done
# Error: Failed to retrieve data. Status code 429
# 374040 - 374160 to redo
# 374160/381216 done
# 374280/381216 done
# Error: Failed to retrieve data. Status code 429
# 374280 - 374400 to redo
# 374400/381216 done
# 374520/381216 done
# Error: Failed to retrieve data. Status code 429
# 374520 - 374640 to redo
# 374640/381216 done
# 374760/381216 done
# Error: Failed to retrieve data. Status code 429
# 374760 - 374880 to redo
# 374880/381216 done
# 375000/381216 done
# Error: Failed to retrieve data. Status code 429
# 375000 - 375120 to redo
# 375120/381216 done
# Error: Failed to retrieve data. Status code 429
# 375120 - 375240 to redo
# 375240/381216 done
# Error: Failed to retrieve data. Status code 429
# 375240 - 375360 to redo
# 375360/381216 done
# Error: Failed to retrieve data. Status code 429
# 375360 - 375480 to redo
# 375480/381216 done
# Error: Failed to retrieve data. Status code 429
# 375480 - 375600 to redo
# 375600/381216 done
# Error: Failed to retrieve data. Status code 429
# 375600 - 375720 to redo
# 375720/381216 done
# 375840/381216 done
# Error: Failed to retrieve data. Status code 429
# 375840 - 375960 to redo
# 375960/381216 done
# Error: Failed to retrieve data. Status code 429
# 375960 - 376080 to redo
# 376080/381216 done
# Error: Failed to retrieve data. Status code 429
# 376080 - 376200 to redo
# 376200/381216 done
# 376320/381216 done
# 376440/381216 done
# Error: Failed to retrieve data. Status code 429
# 376440 - 376560 to redo
# 376560/381216 done
# Error: Failed to retrieve data. Status code 429
# 376560 - 376680 to redo
# 376680/381216 done
# Error: Failed to retrieve data. Status code 429
# 376680 - 376800 to redo
# 376800/381216 done
# 376920/381216 done
# Error: Failed to retrieve data. Status code 429
# 376920 - 377040 to redo
# 377040/381216 done
# Error: Failed to retrieve data. Status code 429
# 377040 - 377160 to redo
# 377160/381216 done
# Error: Failed to retrieve data. Status code 429
# 377160 - 377280 to redo
# 377280/381216 done
# 377400/381216 done
# 377520/381216 done
# Error: Failed to retrieve data. Status code 429
# 377520 - 377640 to redo
# 377640/381216 done
# Error: Failed to retrieve data. Status code 429
# 377640 - 377760 to redo
# 377760/381216 done
# Error: Failed to retrieve data. Status code 429
# 377760 - 377880 to redo
# 377880/381216 done
# 378000/381216 done
# 378120/381216 done
# 378240/381216 done
# 378360/381216 done
# Error: Failed to retrieve data. Status code 429
# 378360 - 378480 to redo
# 378480/381216 done
# Error: Failed to retrieve data. Status code 429
# 378480 - 378600 to redo
# 378600/381216 done
# Error: Failed to retrieve data. Status code 429
# 378600 - 378720 to redo
# 378720/381216 done
# Error: Failed to retrieve data. Status code 429
# 378720 - 378840 to redo
# 378840/381216 done
# 378960/381216 done
# 379080/381216 done
# 379200/381216 done
# 379320/381216 done
# Error: Failed to retrieve data. Status code 429
# 379320 - 379440 to redo
# 379440/381216 done
# Error: Failed to retrieve data. Status code 429
# 379440 - 379560 to redo
# 379560/381216 done
# Error: Failed to retrieve data. Status code 429
# 379560 - 379680 to redo
# 379680/381216 done
# 379800/381216 done
# Error: Failed to retrieve data. Status code 429
# 379800 - 379920 to redo
# 379920/381216 done
# 380040/381216 done
# 380160/381216 done
# Error: Failed to retrieve data. Status code 429
# 380160 - 380280 to redo
# 380280/381216 done
# 380400/381216 done
# 380520/381216 done
# 380640/381216 done
# 380760/381216 done
# 380880/381216 done
# 381000/381216 done
# Error: Failed to retrieve data. Status code 429
# 381000 - 381120 to redo
# 381120/381216 done
# Error: Failed to retrieve data. Status code 429
# 381120 - 381216 to redo
# 381216/381216 done

# %%
# Define query to search for movies based on their freebaseID

generic_query = """
SELECT ?freebaseID
       (SAMPLE(?wikidataID) AS ?wikidataID)
       (SAMPLE(?imdbID) AS ?imdbID)
       (SAMPLE(?wikipediaLink) AS ?wikipediaLink)
       (SAMPLE(?title) AS ?title)
       (SAMPLE(?description) AS ?description)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?runtimes), ",", ""); SEPARATOR=",") AS ?runtime)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?releaseDates), ",", ""); SEPARATOR=",") AS ?releaseDate)
       (GROUP_CONCAT(DISTINCT REPLACE(?genreLabel, ",", ""); SEPARATOR=",") AS ?genres)
       (GROUP_CONCAT(DISTINCT REPLACE(?countryLabel, ",", ""); SEPARATOR=",") AS ?countries)
       (GROUP_CONCAT(DISTINCT REPLACE(?languageLabel, ",", ""); SEPARATOR=",") AS ?languages)
       (GROUP_CONCAT(DISTINCT REPLACE(?companyLabel, ",", ""); SEPARATOR=",") AS ?productionCompanies)
WHERE {
  VALUES ?freebaseID {
|
  }
  
  # ?item wdt:P646 ?freebaseID .
  BIND(STR(?item) AS ?wikidataID)
  
  OPTIONAL { ?item wdt:P136 ?genre . ?genre rdfs:label ?genreLabel FILTER(LANG(?genreLabel) = "en") }
  OPTIONAL { ?item wdt:P495 ?country . ?country rdfs:label ?countryLabel FILTER(LANG(?countryLabel) = "en") }
  OPTIONAL { ?item wdt:P364 ?language . ?language rdfs:label ?languageLabel FILTER(LANG(?languageLabel) = "en") }
  OPTIONAL { ?item wdt:P272 ?company . ?company rdfs:label ?companyLabel FILTER(LANG(?companyLabel) = "en") }
  OPTIONAL { ?item wdt:P577 ?releaseDates }
  OPTIONAL { ?item wdt:P2047 ?runtimes }
  
  OPTIONAL {
    # ?wikipediaLink schema:about ?item ;
                   schema:inLanguage "en" ;
                   schema:isPartOf <https://en.wikipedia.org/> .
  }

  # ?item rdfs:label ?title FILTER(LANG(?title) = "en") .
  OPTIONAL { ?item schema:description ?description FILTER(LANG(?description) = "en") }
}
GROUP BY ?freebaseID
"""

# %%
# We run the above defined SPARQL query on groups of 120 freebaseIDs, the results are saved in temporary files

freebase_ids = list(set(pd.read_csv(DATA_PATH + 'movie.metadata.tsv', sep='\t', header=None)[1].values).difference(set(pd.read_csv(DATA_PATH + "wikidata_imdbID.csv")['freebaseID'].values)))

temp_files_name = "tempFiles/wikidata_imdbID_temp_"

n = len(freebase_ids)
step = 120

c = 1
low = step*(c-1)
while low < n:
    up = min(low + step, n)

    ids_string = "\n".join([f"\"{freebase_ids[i]}\"" for i in range(low,up)])
    
    query = generic_query.replace("|", ids_string)
    
    success = download_wikidata_sparql_csv(query, f"{DATA_PATH}{temp_files_name}{3178+c-1:06d}.csv")
    
    if success:
        low = up
        c += 1
        print(f"{up}/{n} done")
    else:
        print(f"{low} - {up} to redo")

    time.sleep(0.25)
# Out:
# 120/21998 done
# 240/21998 done
# 360/21998 done
# 480/21998 done
# 600/21998 done
# 720/21998 done
# 840/21998 done
# 960/21998 done
# 1080/21998 done
# 1200/21998 done
# 1320/21998 done
# 1440/21998 done
# 1560/21998 done
# 1680/21998 done
# 1800/21998 done
# 1920/21998 done
# 2040/21998 done
# 2160/21998 done
# 2280/21998 done
# 2400/21998 done
# 2520/21998 done
# 2640/21998 done
# 2760/21998 done
# 2880/21998 done
# 3000/21998 done
# 3120/21998 done
# 3240/21998 done
# 3360/21998 done
# 3480/21998 done
# 3600/21998 done
# 3720/21998 done
# 3840/21998 done
# 3960/21998 done
# 4080/21998 done
# 4200/21998 done
# 4320/21998 done
# 4440/21998 done
# 4560/21998 done
# 4680/21998 done
# 4800/21998 done
# 4920/21998 done
# 5040/21998 done
# 5160/21998 done
# 5280/21998 done
# 5400/21998 done
# 5520/21998 done
# 5640/21998 done
# 5760/21998 done
# 5880/21998 done
# 6000/21998 done
# 6120/21998 done
# 6240/21998 done
# 6360/21998 done
# 6480/21998 done
# 6600/21998 done
# 6720/21998 done
# 6840/21998 done
# 6960/21998 done
# 7080/21998 done
# 7200/21998 done
# 7320/21998 done
# 7440/21998 done
# 7560/21998 done
# 7680/21998 done
# 7800/21998 done
# 7920/21998 done
# 8040/21998 done
# 8160/21998 done
# 8280/21998 done
# 8400/21998 done
# 8520/21998 done
# 8640/21998 done
# 8760/21998 done
# 8880/21998 done
# 9000/21998 done
# 9120/21998 done
# 9240/21998 done
# 9360/21998 done
# 9480/21998 done
# 9600/21998 done
# 9720/21998 done
# 9840/21998 done
# 9960/21998 done
# 10080/21998 done
# 10200/21998 done
# 10320/21998 done
# 10440/21998 done
# 10560/21998 done
# 10680/21998 done
# 10800/21998 done
# 10920/21998 done
# 11040/21998 done
# 11160/21998 done
# 11280/21998 done
# 11400/21998 done
# 11520/21998 done
# 11640/21998 done
# 11760/21998 done
# 11880/21998 done
# 12000/21998 done
# 12120/21998 done
# 12240/21998 done
# 12360/21998 done
# 12480/21998 done
# 12600/21998 done
# 12720/21998 done
# 12840/21998 done
# 12960/21998 done
# 13080/21998 done
# 13200/21998 done
# 13320/21998 done
# 13440/21998 done
# 13560/21998 done
# 13680/21998 done
# 13800/21998 done
# 13920/21998 done
# 14040/21998 done
# 14160/21998 done
# 14280/21998 done
# 14400/21998 done
# 14520/21998 done
# 14640/21998 done
# 14760/21998 done
# 14880/21998 done
# 15000/21998 done
# 15120/21998 done
# 15240/21998 done
# 15360/21998 done
# 15480/21998 done
# 15600/21998 done
# 15720/21998 done
# 15840/21998 done
# 15960/21998 done
# 16080/21998 done
# 16200/21998 done
# 16320/21998 done
# 16440/21998 done
# 16560/21998 done
# 16680/21998 done
# 16800/21998 done
# 16920/21998 done
# 17040/21998 done
# 17160/21998 done
# 17280/21998 done
# 17400/21998 done
# 17520/21998 done
# 17640/21998 done
# 17760/21998 done
# 17880/21998 done
# 18000/21998 done
# 18120/21998 done
# 18240/21998 done
# 18360/21998 done
# 18480/21998 done
# 18600/21998 done
# 18720/21998 done
# 18840/21998 done
# 18960/21998 done
# 19080/21998 done
# 19200/21998 done
# 19320/21998 done
# 19440/21998 done
# 19560/21998 done
# 19680/21998 done
# 19800/21998 done
# 19920/21998 done
# 20040/21998 done
# 20160/21998 done
# 20280/21998 done
# 20400/21998 done
# 20520/21998 done
# 20640/21998 done
# 20760/21998 done
# 20880/21998 done
# 21000/21998 done
# 21120/21998 done
# 21240/21998 done
# 21360/21998 done
# 21480/21998 done
# 21600/21998 done
# 21720/21998 done
# 21840/21998 done
# 21960/21998 done
# 21998/21998 done

# %%
# Concatenate all the temporary files in a single csv file

pd.concat([pd.read_csv(f"{DATA_PATH}{temp_files_name}{i:06d}.csv") for i in range(1,3362)], ignore_index=True).to_csv(DATA_PATH + "wikidata_freebaseID_imdbID.csv", index=False)

# %% [markdown]
# # Wikidata scraping - Casts

# %%
# Define query to search for casts and directors based on movies' imdbID

generic_query = """
SELECT ?film ?freebaseFilmID ?imdbID ?filmLabel ?person ?freebasePersonID ?personIMDbID ?personLabel ?role ?characterName
WHERE {
  VALUES ?imdbID {
|
  }

  # ?film wdt:P345 ?imdbID .
  OPTIONAL { ?film wdt:P646 ?freebaseFilmID }
  {
    # ?film wdt:P57 ?person .
    BIND("director" AS ?role)
  }
  UNION
  {
    # ?film wdt:P161 ?person .
    BIND("actor" AS ?role)
    OPTIONAL {
      # ?film p:P161 ?castStatement .
      # ?castStatement ps:P161 ?person ;
                     pq:P4633 ?characterName .
    }
  }

  OPTIONAL { ?person wdt:P646 ?freebasePersonID }
  OPTIONAL { ?person wdt:P345 ?personIMDbID }

  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
"""

# %%
# We run the above defined SPARQL query on groups of 200 imdbIDs, the results are saved in temporary files

movies_complete = pd.read_csv(DATA_PATH + "movies_complete.tsv", sep='\t')
imdb_ids_movie = movies_complete["imdb_id_movie"].dropna().values

temp_files_name = "tempFiles/wikidata_cast_temp_"

n = len(imdb_ids_movie)
step = 200

c = 1
low = step*(c-1)
while low < n:
    up = min(low + step, n)

    ids_string = "\n".join([f"\"{imdb_ids_movie[i]}\"" for i in range(low,up)])
    
    query = generic_query.replace("|", ids_string)
    
    success = download_wikidata_sparql_csv(query, f"{DATA_PATH}{temp_files_name}{c:06d}.csv")
    
    if success:
        low = up
        c += 1
        print(f"{up}/{n} done")
    else:
        print(f"{low} - {up} to redo")

    time.sleep(0.25)
# Out:
# 200/65454 done
# 400/65454 done
# 600/65454 done
# 800/65454 done
# 1000/65454 done
# 1200/65454 done
# 1400/65454 done
# 1600/65454 done
# 1800/65454 done
# 2000/65454 done
# 2200/65454 done
# 2400/65454 done
# 2600/65454 done
# 2800/65454 done
# 3000/65454 done
# 3200/65454 done
# 3400/65454 done
# 3600/65454 done
# 3800/65454 done
# 4000/65454 done
# 4200/65454 done
# 4400/65454 done
# 4600/65454 done
# 4800/65454 done
# 5000/65454 done
# 5200/65454 done
# 5400/65454 done
# 5600/65454 done
# 5800/65454 done
# 6000/65454 done
# 6200/65454 done
# 6400/65454 done
# 6600/65454 done
# 6800/65454 done
# 7000/65454 done
# 7200/65454 done
# 7400/65454 done
# 7600/65454 done
# 7800/65454 done
# 8000/65454 done
# 8200/65454 done
# 8400/65454 done
# 8600/65454 done
# 8800/65454 done
# 9000/65454 done
# 9200/65454 done
# 9400/65454 done
# 9600/65454 done
# 9800/65454 done
# 10000/65454 done
# 10200/65454 done
# 10400/65454 done
# 10600/65454 done
# 10800/65454 done
# 11000/65454 done
# 11200/65454 done
# 11400/65454 done
# 11600/65454 done
# 11800/65454 done
# 12000/65454 done
# 12200/65454 done
# 12400/65454 done
# 12600/65454 done
# 12800/65454 done
# 13000/65454 done
# 13200/65454 done
# 13400/65454 done
# 13600/65454 done
# 13800/65454 done
# 14000/65454 done
# 14200/65454 done
# 14400/65454 done
# 14600/65454 done
# 14800/65454 done
# 15000/65454 done
# 15200/65454 done
# 15400/65454 done
# 15600/65454 done
# 15800/65454 done
# 16000/65454 done
# 16200/65454 done
# 16400/65454 done
# 16600/65454 done
# 16800/65454 done
# 17000/65454 done
# 17200/65454 done
# 17400/65454 done
# 17600/65454 done
# 17800/65454 done
# 18000/65454 done
# 18200/65454 done
# 18400/65454 done
# 18600/65454 done
# 18800/65454 done
# 19000/65454 done
# 19200/65454 done
# 19400/65454 done
# 19600/65454 done
# 19800/65454 done
# 20000/65454 done
# 20200/65454 done
# 20400/65454 done
# 20600/65454 done
# 20800/65454 done
# 21000/65454 done
# 21200/65454 done
# 21400/65454 done
# 21600/65454 done
# 21800/65454 done
# 22000/65454 done
# 22200/65454 done
# 22400/65454 done
# 22600/65454 done
# 22800/65454 done
# 23000/65454 done
# 23200/65454 done
# 23400/65454 done
# 23600/65454 done
# 23800/65454 done
# 24000/65454 done
# 24200/65454 done
# 24400/65454 done
# 24600/65454 done
# 24800/65454 done
# 25000/65454 done
# 25200/65454 done
# 25400/65454 done
# 25600/65454 done
# 25800/65454 done
# 26000/65454 done
# 26200/65454 done
# 26400/65454 done
# 26600/65454 done
# 26800/65454 done
# 27000/65454 done
# 27200/65454 done
# 27400/65454 done
# 27600/65454 done
# 27800/65454 done
# 28000/65454 done
# 28200/65454 done
# 28400/65454 done
# 28600/65454 done
# 28800/65454 done
# 29000/65454 done
# 29200/65454 done
# 29400/65454 done
# 29600/65454 done
# 29800/65454 done
# 30000/65454 done
# 30200/65454 done
# 30400/65454 done
# 30600/65454 done
# 30800/65454 done
# 31000/65454 done
# 31200/65454 done
# 31400/65454 done
# 31600/65454 done
# 31800/65454 done
# 32000/65454 done
# 32200/65454 done
# 32400/65454 done
# 32600/65454 done
# 32800/65454 done
# 33000/65454 done
# 33200/65454 done
# 33400/65454 done
# 33600/65454 done
# 33800/65454 done
# 34000/65454 done
# 34200/65454 done
# 34400/65454 done
# 34600/65454 done
# 34800/65454 done
# 35000/65454 done
# 35200/65454 done
# 35400/65454 done
# 35600/65454 done
# 35800/65454 done
# 36000/65454 done
# 36200/65454 done
# 36400/65454 done
# 36600/65454 done
# 36800/65454 done
# 37000/65454 done
# 37200/65454 done
# 37400/65454 done
# 37600/65454 done
# 37800/65454 done
# 38000/65454 done
# 38200/65454 done
# 38400/65454 done
# 38600/65454 done
# 38800/65454 done
# 39000/65454 done
# 39200/65454 done
# 39400/65454 done
# 39600/65454 done
# 39800/65454 done
# 40000/65454 done
# 40200/65454 done
# 40400/65454 done
# 40600/65454 done
# 40800/65454 done
# 41000/65454 done
# 41200/65454 done
# 41400/65454 done
# 41600/65454 done
# 41800/65454 done
# 42000/65454 done
# 42200/65454 done
# 42400/65454 done
# 42600/65454 done
# 42800/65454 done
# 43000/65454 done
# 43200/65454 done
# 43400/65454 done
# 43600/65454 done
# 43800/65454 done
# 44000/65454 done
# 44200/65454 done
# 44400/65454 done
# 44600/65454 done
# 44800/65454 done
# 45000/65454 done
# 45200/65454 done
# 45400/65454 done
# 45600/65454 done
# 45800/65454 done
# 46000/65454 done
# 46200/65454 done
# 46400/65454 done
# 46600/65454 done
# 46800/65454 done
# 47000/65454 done
# 47200/65454 done
# 47400/65454 done
# 47600/65454 done
# 47800/65454 done
# 48000/65454 done
# 48200/65454 done
# 48400/65454 done
# 48600/65454 done
# 48800/65454 done
# 49000/65454 done
# 49200/65454 done
# 49400/65454 done
# 49600/65454 done
# 49800/65454 done
# 50000/65454 done
# 50200/65454 done
# 50400/65454 done
# 50600/65454 done
# 50800/65454 done
# 51000/65454 done
# 51200/65454 done
# 51400/65454 done
# 51600/65454 done
# 51800/65454 done
# 52000/65454 done
# 52200/65454 done
# 52400/65454 done
# 52600/65454 done
# 52800/65454 done
# 53000/65454 done
# 53200/65454 done
# 53400/65454 done
# 53600/65454 done
# 53800/65454 done
# 54000/65454 done
# 54200/65454 done
# 54400/65454 done
# 54600/65454 done
# 54800/65454 done
# 55000/65454 done
# 55200/65454 done
# 55400/65454 done
# 55600/65454 done
# 55800/65454 done
# 56000/65454 done
# 56200/65454 done
# 56400/65454 done
# 56600/65454 done
# 56800/65454 done
# 57000/65454 done
# 57200/65454 done
# 57400/65454 done
# 57600/65454 done
# 57800/65454 done
# 58000/65454 done
# 58200/65454 done
# 58400/65454 done
# 58600/65454 done
# 58800/65454 done
# 59000/65454 done
# 59200/65454 done
# 59400/65454 done
# 59600/65454 done
# 59800/65454 done
# 60000/65454 done
# 60200/65454 done
# 60400/65454 done
# 60600/65454 done
# 60800/65454 done
# 61000/65454 done
# 61200/65454 done
# 61400/65454 done
# 61600/65454 done
# 61800/65454 done
# 62000/65454 done
# 62200/65454 done
# 62400/65454 done
# 62600/65454 done
# 62800/65454 done
# 63000/65454 done
# 63200/65454 done
# 63400/65454 done
# 63600/65454 done
# 63800/65454 done
# 64000/65454 done
# 64200/65454 done
# 64400/65454 done
# 64600/65454 done
# 64800/65454 done
# 65000/65454 done
# 65200/65454 done
# 65400/65454 done
# 65454/65454 done

# %%
# Concatenate all the temporary files and use movies_complete to translate imdbIDs into freebaseIDs, save the result in a csv file

df = pd.concat([pd.read_csv(f"{DATA_PATH}{temp_files_name}{i:06d}.csv") for i in range(1,329)], ignore_index=True)

translator = pd.Series(movies_complete.freebase_id_movie.values, index=movies_complete.imdb_id_movie.values)
df["freebaseFilmID"] = df.apply(lambda row: translator[row["imdbID"]] if pd.isna(row["freebaseFilmID"]) else row["freebaseFilmID"], axis=1)

df.to_csv(DATA_PATH + "wikidata_cast_imdb.csv", index=False)

# %%
# Define query to search for casts and directors based on movies' freebaseID

generic_query = """
SELECT ?film ?freebaseFilmID ?imdbID ?filmLabel ?person ?freebasePersonID ?personIMDbID ?personLabel ?role ?characterName
WHERE {
  VALUES ?freebaseFilmID {
|
  }

  # ?film wdt:P646 ?freebaseFilmID .
  OPTIONAL { ?film wdt:P345 ?imdbID }
  {
    # ?film wdt:P57 ?person .
    BIND("director" AS ?role)
  }
  UNION
  {
    # ?film wdt:P161 ?person .
    BIND("actor" AS ?role)
    OPTIONAL {
      # ?film p:P161 ?castStatement .
      # ?castStatement ps:P161 ?person ;
                     pq:P4633 ?characterName .
    }
  }

  OPTIONAL { ?person wdt:P646 ?freebasePersonID }
  OPTIONAL { ?person wdt:P345 ?personIMDbID }

  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
"""

# %%
# We run the above defined SPARQL query on groups of 200 freebaseIDs, the results are saved in temporary files

freebase_ids = list(set(movies_complete["freebase_id_movie"].dropna().values).difference(set(pd.read_csv(DATA_PATH + "wikidata_cast_imdb.csv")["freebaseFilmID"].dropna().values)))

temp_files_name = "tempFiles/wikidata_cast_temp_"

n = len(freebase_ids)
step = 200

c = 1
low = step*(c-1)
while low < n:
    up = min(low + step, n)

    ids_string = "\n".join([f"\"{freebase_ids[i]}\"" for i in range(low,up)])
    
    query = generic_query.replace("|", ids_string)
    
    success = download_wikidata_sparql_csv(query, f"{DATA_PATH}{temp_files_name}{329+c-1:06d}.csv")
    
    if success:
        low = up
        c += 1
        print(f"{up}/{n} done")
    else:
        print(f"{low} - {up} to redo")

    time.sleep(0.25)
# Out:
# 200/15949 done
# 400/15949 done
# 600/15949 done
# 800/15949 done
# 1000/15949 done
# 1200/15949 done
# 1400/15949 done
# 1600/15949 done
# 1800/15949 done
# 2000/15949 done
# Error: Failed to retrieve data. Status code 429
# 2000 - 2200 to redo
# Error: Failed to retrieve data. Status code 429
# 2000 - 2200 to redo
# 2200/15949 done
# Error: Failed to retrieve data. Status code 429
# 2200 - 2400 to redo
# Error: Failed to retrieve data. Status code 429
# 2200 - 2400 to redo
# 2400/15949 done
# Error: Failed to retrieve data. Status code 429
# 2400 - 2600 to redo
# Error: Failed to retrieve data. Status code 429
# 2400 - 2600 to redo
# 2600/15949 done
# Error: Failed to retrieve data. Status code 429
# 2600 - 2800 to redo
# Error: Failed to retrieve data. Status code 429
# 2600 - 2800 to redo
# 2800/15949 done
# Error: Failed to retrieve data. Status code 429
# 2800 - 3000 to redo
# 3000/15949 done
# Error: Failed to retrieve data. Status code 429
# 3000 - 3200 to redo
# 3200/15949 done
# Error: Failed to retrieve data. Status code 429
# 3200 - 3400 to redo
# 3400/15949 done
# Error: Failed to retrieve data. Status code 429
# 3400 - 3600 to redo
# 3600/15949 done
# Error: Failed to retrieve data. Status code 429
# 3600 - 3800 to redo
# 3800/15949 done
# Error: Failed to retrieve data. Status code 429
# 3800 - 4000 to redo
# 4000/15949 done
# Error: Failed to retrieve data. Status code 429
# 4000 - 4200 to redo
# 4200/15949 done
# Error: Failed to retrieve data. Status code 429
# 4200 - 4400 to redo
# 4400/15949 done
# Error: Failed to retrieve data. Status code 429
# 4400 - 4600 to redo
# 4600/15949 done
# Error: Failed to retrieve data. Status code 429
# 4600 - 4800 to redo
# 4800/15949 done
# Error: Failed to retrieve data. Status code 429
# 4800 - 5000 to redo
# 5000/15949 done
# Error: Failed to retrieve data. Status code 429
# 5000 - 5200 to redo
# 5200/15949 done
# Error: Failed to retrieve data. Status code 429
# 5200 - 5400 to redo
# 5400/15949 done
# Error: Failed to retrieve data. Status code 429
# 5400 - 5600 to redo
# 5600/15949 done
# Error: Failed to retrieve data. Status code 429
# 5600 - 5800 to redo
# 5800/15949 done
# Error: Failed to retrieve data. Status code 429
# 5800 - 6000 to redo
# 6000/15949 done
# Error: Failed to retrieve data. Status code 429
# 6000 - 6200 to redo
# 6200/15949 done
# Error: Failed to retrieve data. Status code 429
# 6200 - 6400 to redo
# 6400/15949 done
# Error: Failed to retrieve data. Status code 429
# 6400 - 6600 to redo
# 6600/15949 done
# Error: Failed to retrieve data. Status code 429
# 6600 - 6800 to redo
# 6800/15949 done
# Error: Failed to retrieve data. Status code 429
# 6800 - 7000 to redo
# 7000/15949 done
# Error: Failed to retrieve data. Status code 429
# 7000 - 7200 to redo
# 7200/15949 done
# 7400/15949 done
# Error: Failed to retrieve data. Status code 429
# 7400 - 7600 to redo
# 7600/15949 done
# Error: Failed to retrieve data. Status code 429
# 7600 - 7800 to redo
# 7800/15949 done
# 8000/15949 done
# Error: Failed to retrieve data. Status code 429
# 8000 - 8200 to redo
# 8200/15949 done
# Error: Failed to retrieve data. Status code 429
# 8200 - 8400 to redo
# 8400/15949 done
# Error: Failed to retrieve data. Status code 429
# 8400 - 8600 to redo
# 8600/15949 done
# Error: Failed to retrieve data. Status code 429
# 8600 - 8800 to redo
# 8800/15949 done
# Error: Failed to retrieve data. Status code 429
# 8800 - 9000 to redo
# 9000/15949 done
# Error: Failed to retrieve data. Status code 429
# 9000 - 9200 to redo
# Error: Failed to retrieve data. Status code 429
# 9000 - 9200 to redo
# 9200/15949 done
# Error: Failed to retrieve data. Status code 429
# 9200 - 9400 to redo
# 9400/15949 done
# Error: Failed to retrieve data. Status code 429
# 9400 - 9600 to redo
# Error: Failed to retrieve data. Status code 429
# 9400 - 9600 to redo
# 9600/15949 done
# Error: Failed to retrieve data. Status code 429
# 9600 - 9800 to redo
# Error: Failed to retrieve data. Status code 429
# 9600 - 9800 to redo
# 9800/15949 done
# Error: Failed to retrieve data. Status code 429
# 9800 - 10000 to redo
# Error: Failed to retrieve data. Status code 429
# 9800 - 10000 to redo
# 10000/15949 done
# Error: Failed to retrieve data. Status code 429
# 10000 - 10200 to redo
# Error: Failed to retrieve data. Status code 429
# 10000 - 10200 to redo
# 10200/15949 done
# Error: Failed to retrieve data. Status code 429
# 10200 - 10400 to redo
# Error: Failed to retrieve data. Status code 429
# 10200 - 10400 to redo
# 10400/15949 done
# Error: Failed to retrieve data. Status code 429
# 10400 - 10600 to redo
# Error: Failed to retrieve data. Status code 429
# 10400 - 10600 to redo
# 10600/15949 done
# Error: Failed to retrieve data. Status code 429
# 10600 - 10800 to redo
# Error: Failed to retrieve data. Status code 429
# 10600 - 10800 to redo
# 10800/15949 done
# Error: Failed to retrieve data. Status code 429
# 10800 - 11000 to redo
# Error: Failed to retrieve data. Status code 429
# 10800 - 11000 to redo
# 11000/15949 done
# Error: Failed to retrieve data. Status code 429
# 11000 - 11200 to redo
# Error: Failed to retrieve data. Status code 429
# 11000 - 11200 to redo
# 11200/15949 done
# Error: Failed to retrieve data. Status code 429
# 11200 - 11400 to redo
# Error: Failed to retrieve data. Status code 429
# 11200 - 11400 to redo
# 11400/15949 done
# Error: Failed to retrieve data. Status code 429
# 11400 - 11600 to redo
# Error: Failed to retrieve data. Status code 429
# 11400 - 11600 to redo
# 11600/15949 done
# Error: Failed to retrieve data. Status code 429
# 11600 - 11800 to redo
# Error: Failed to retrieve data. Status code 429
# 11600 - 11800 to redo
# 11800/15949 done
# Error: Failed to retrieve data. Status code 429
# 11800 - 12000 to redo
# Error: Failed to retrieve data. Status code 429
# 11800 - 12000 to redo
# 12000/15949 done
# Error: Failed to retrieve data. Status code 429
# 12000 - 12200 to redo
# Error: Failed to retrieve data. Status code 429
# 12000 - 12200 to redo
# 12200/15949 done
# Error: Failed to retrieve data. Status code 429
# 12200 - 12400 to redo
# Error: Failed to retrieve data. Status code 429
# 12200 - 12400 to redo
# 12400/15949 done
# Error: Failed to retrieve data. Status code 429
# 12400 - 12600 to redo
# Error: Failed to retrieve data. Status code 429
# 12400 - 12600 to redo
# 12600/15949 done
# Error: Failed to retrieve data. Status code 429
# 12600 - 12800 to redo
# Error: Failed to retrieve data. Status code 429
# 12600 - 12800 to redo
# 12800/15949 done
# Error: Failed to retrieve data. Status code 429
# 12800 - 13000 to redo
# Error: Failed to retrieve data. Status code 429
# 12800 - 13000 to redo
# 13000/15949 done
# Error: Failed to retrieve data. Status code 429
# 13000 - 13200 to redo
# Error: Failed to retrieve data. Status code 429
# 13000 - 13200 to redo
# 13200/15949 done
# Error: Failed to retrieve data. Status code 429
# 13200 - 13400 to redo
# Error: Failed to retrieve data. Status code 429
# 13200 - 13400 to redo
# 13400/15949 done
# Error: Failed to retrieve data. Status code 429
# 13400 - 13600 to redo
# Error: Failed to retrieve data. Status code 429
# 13400 - 13600 to redo
# 13600/15949 done
# Error: Failed to retrieve data. Status code 429
# 13600 - 13800 to redo
# Error: Failed to retrieve data. Status code 429
# 13600 - 13800 to redo
# 13800/15949 done
# Error: Failed to retrieve data. Status code 429
# 13800 - 14000 to redo
# Error: Failed to retrieve data. Status code 429
# 13800 - 14000 to redo
# 14000/15949 done
# Error: Failed to retrieve data. Status code 429
# 14000 - 14200 to redo
# Error: Failed to retrieve data. Status code 429
# 14000 - 14200 to redo
# 14200/15949 done
# Error: Failed to retrieve data. Status code 429
# 14200 - 14400 to redo
# Error: Failed to retrieve data. Status code 429
# 14200 - 14400 to redo
# 14400/15949 done
# Error: Failed to retrieve data. Status code 429
# 14400 - 14600 to redo
# Error: Failed to retrieve data. Status code 429
# 14400 - 14600 to redo
# 14600/15949 done
# Error: Failed to retrieve data. Status code 429
# 14600 - 14800 to redo
# Error: Failed to retrieve data. Status code 429
# 14600 - 14800 to redo
# 14800/15949 done
# Error: Failed to retrieve data. Status code 429
# 14800 - 15000 to redo
# Error: Failed to retrieve data. Status code 429
# 14800 - 15000 to redo
# 15000/15949 done
# Error: Failed to retrieve data. Status code 429
# 15000 - 15200 to redo
# Error: Failed to retrieve data. Status code 429
# 15000 - 15200 to redo
# 15200/15949 done
# Error: Failed to retrieve data. Status code 429
# 15200 - 15400 to redo
# Error: Failed to retrieve data. Status code 429
# 15200 - 15400 to redo
# 15400/15949 done
# Error: Failed to retrieve data. Status code 429
# 15400 - 15600 to redo
# Error: Failed to retrieve data. Status code 429
# 15400 - 15600 to redo
# 15600/15949 done
# Error: Failed to retrieve data. Status code 429
# 15600 - 15800 to redo
# Error: Failed to retrieve data. Status code 429
# 15600 - 15800 to redo
# 15800/15949 done
# Error: Failed to retrieve data. Status code 429
# 15800 - 15949 to redo
# Error: Failed to retrieve data. Status code 429
# 15800 - 15949 to redo
# 15949/15949 done

# %%
# Concatenating the new temporary files we find that no rows have been added to the one we had before

df = pd.concat([pd.read_csv(f"{DATA_PATH}{temp_files_name}{i:06d}.csv") for i in range(329,409)], ignore_index=True)

print(len(df))
# Out:
# 0

# %% [markdown]
# # Wikidata scraping - People

# %%
# Define query to search for people based on their imdbID

generic_query = """
SELECT ?imdbID
       (SAMPLE(?wikidataID) AS ?wikidataID)
       (SAMPLE(?freebaseID) AS ?freebaseID)
       (SAMPLE(?wikipediaLink) AS ?wikipediaLink)
       (SAMPLE(?itemLabel) AS ?nameSurname)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?givenNameLabel), ",", ""); SEPARATOR=",") AS ?givenName)
       (SAMPLE(?familyNameLabel) AS ?familyName)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?birthDates), ",", ""); SEPARATOR=",") AS ?birthDate)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?genderLabel), ",", ""); SEPARATOR=",") AS ?gender)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?citizenshipLabel), ",", ""); SEPARATOR=",") AS ?citizenship)
       (SAMPLE(?placeOfBirthLabel) AS ?placeOfBirth)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?nativeLanguageLabel), ",", ""); SEPARATOR=",") AS ?nativeLanguage)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?deathDates), ",", ""); SEPARATOR=",") AS ?deathDate)
WHERE {
  VALUES ?imdbID {
|
  }

  # ?item wdt:P345 ?imdbID .
  BIND(STR(?item) AS ?wikidataID)

  OPTIONAL { ?item wdt:P646 ?freebaseID }

  OPTIONAL { ?item wdt:P735 ?givenName . ?givenName rdfs:label ?givenNameLabel FILTER(LANG(?givenNameLabel) = "en") }
  OPTIONAL { ?item wdt:P734 ?familyName . ?familyName rdfs:label ?familyNameLabel FILTER(LANG(?familyNameLabel) = "en") }

  OPTIONAL { ?item wdt:P569 ?birthDates }
  OPTIONAL { ?item wdt:P21 ?gender . ?gender rdfs:label ?genderLabel FILTER(LANG(?genderLabel) = "en") }
  OPTIONAL { ?item wdt:P27 ?citizenship . ?citizenship rdfs:label ?citizenshipLabel FILTER(LANG(?citizenshipLabel) = "en") }
  OPTIONAL { ?item wdt:P19 ?placeOfBirth . ?placeOfBirth rdfs:label ?placeOfBirthLabel FILTER(LANG(?placeOfBirthLabel) = "en") }
  OPTIONAL { ?item wdt:P103 ?nativeLanguage . ?nativeLanguage rdfs:label ?nativeLanguageLabel FILTER(LANG(?nativeLanguageLabel) = "en") }
  OPTIONAL { ?item wdt:P570 ?deathDates }

  OPTIONAL {
    # ?wikipediaLink schema:about ?item ;
                   schema:inLanguage "en" ;
                   schema:isPartOf <https://en.wikipedia.org/> .
  }

  # ?item rdfs:label ?itemLabel FILTER(LANG(?itemLabel) = "en") .
}
GROUP BY ?imdbID
"""

# %%
# We run the above defined SPARQL query on groups of 200 imdbIDs, the results are saved in temporary files

movie_actor_complete = pd.read_csv(DATA_PATH + "movie_actor_complete.tsv", sep='\t')
imdb_ids = set(movie_actor_complete.imdb_id_actor.dropna())
freebase_ids = movie_actor_complete.freebase_id_actor[~movie_actor_complete.imdb_id_actor.isin(imdb_ids).dropna()].values
imdb_ids = list(imdb_ids)

temp_files_name = "tempFiles/wikidata_people_temp_"

n = len(imdb_ids)
step = 200

c = 233
low = step*(c-1)
while low < n:
    up = min(low + step, n)

    ids_string = "\n".join([f"\"{imdb_ids[i]}\"" for i in range(low,up)])
    
    query = generic_query.replace("|", ids_string)

    success = False
    try:
        success = download_wikidata_sparql_csv(query, f"{DATA_PATH}{temp_files_name}{c:06d}.csv")
    except:
        time.sleep(1)
    
    if success:
        low = up
        c += 1
        print(f"{up}/{n} done")
    else:
        print(f"{low} - {up} to redo")

    time.sleep(0.25)
# Out:
# 46600/103877 done
# 46800/103877 done
# 47000/103877 done
# 47200/103877 done
# 47400/103877 done
# 47600/103877 done
# 47800/103877 done
# 48000/103877 done
# 48200/103877 done
# 48400/103877 done
# 48600/103877 done
# 48800/103877 done
# 49000/103877 done
# 49200/103877 done
# 49400/103877 done
# 49600/103877 done
# 49800/103877 done
# 50000/103877 done
# 50200/103877 done
# 50400/103877 done
# 50600/103877 done
# 50800/103877 done
# 51000/103877 done
# 51200/103877 done
# 51400/103877 done
# 51600/103877 done
# 51800/103877 done
# 52000/103877 done
# 52200/103877 done
# 52400/103877 done
# 52600/103877 done
# 52800/103877 done
# 53000/103877 done
# 53200/103877 done
# 53400/103877 done
# 53600/103877 done
# 53800/103877 done
# 54000/103877 done
# 54200/103877 done
# 54400/103877 done
# 54600/103877 done
# 54800/103877 done
# 55000/103877 done
# 55200/103877 done
# 55400/103877 done
# 55600/103877 done
# 55800/103877 done
# 56000/103877 done
# 56200/103877 done
# 56400/103877 done
# 56600/103877 done
# 56800/103877 done
# 57000/103877 done
# 57200/103877 done
# 57400/103877 done
# 57600/103877 done
# 57800/103877 done
# 58000/103877 done
# 58200/103877 done
# 58400/103877 done
# 58600/103877 done
# 58800/103877 done
# 59000/103877 done
# 59200/103877 done
# 59400/103877 done
# 59600/103877 done
# 59800/103877 done
# 60000/103877 done
# 60200/103877 done
# 60400/103877 done
# 60600/103877 done
# 60800/103877 done
# 61000/103877 done
# 61200/103877 done
# 61400/103877 done
# 61600/103877 done
# 61800/103877 done
# 62000/103877 done
# 62200/103877 done
# 62400/103877 done
# 62600/103877 done
# 62800/103877 done
# 63000/103877 done
# 63200/103877 done
# 63400/103877 done
# 63600/103877 done
# 63800/103877 done
# 64000/103877 done
# 64200/103877 done
# 64400/103877 done
# 64600/103877 done
# 64800/103877 done
# 65000/103877 done
# 65200/103877 done
# 65400/103877 done
# 65600/103877 done
# 65800/103877 done
# 66000/103877 done
# 66200/103877 done
# 66400/103877 done
# 66600/103877 done
# 66800/103877 done
# 67000/103877 done
# 67200/103877 done
# 67400/103877 done
# 67600/103877 done
# 67800/103877 done
# 68000/103877 done
# 68200/103877 done
# 68400/103877 done
# 68600/103877 done
# 68800/103877 done
# 69000/103877 done
# 69200/103877 done
# 69400/103877 done
# 69600/103877 done
# 69800/103877 done
# 70000/103877 done
# 70200/103877 done
# 70400/103877 done
# 70600/103877 done
# 70800/103877 done
# 71000/103877 done
# 71200/103877 done
# 71400/103877 done
# 71600/103877 done
# 71800/103877 done
# 72000/103877 done
# 72200/103877 done
# 72400/103877 done
# 72600/103877 done
# 72800/103877 done
# 73000/103877 done
# 73200/103877 done
# 73400/103877 done
# 73600/103877 done
# 73800/103877 done
# 74000/103877 done
# 74200/103877 done
# 74400/103877 done
# 74600/103877 done
# 74800/103877 done
# 75000/103877 done
# 75200/103877 done
# 75400/103877 done
# 75600/103877 done
# 75800/103877 done
# 76000/103877 done
# 76200/103877 done
# 76400/103877 done
# 76600/103877 done
# 76800/103877 done
# 77000/103877 done
# 77200/103877 done
# 77400/103877 done
# 77600/103877 done
# 77800/103877 done
# 78000/103877 done
# 78200/103877 done
# 78400/103877 done
# 78600/103877 done
# 78800/103877 done
# 79000/103877 done
# 79200/103877 done
# 79400/103877 done
# 79600/103877 done
# 79800/103877 done
# 80000/103877 done
# 80200/103877 done
# 80400/103877 done
# 80600/103877 done
# 80800/103877 done
# 81000/103877 done
# 81200/103877 done
# 81400/103877 done
# 81600/103877 done
# 81800/103877 done
# 82000/103877 done
# 82200/103877 done
# 82400/103877 done
# 82600/103877 done
# 82800/103877 done
# 83000/103877 done
# 83200/103877 done
# 83400/103877 done
# 83600/103877 done
# 83800/103877 done
# 84000/103877 done
# 84200/103877 done
# 84400/103877 done
# 84600/103877 done
# 84800/103877 done
# 85000/103877 done
# 85200/103877 done
# 85400/103877 done
# 85600/103877 done
# 85800/103877 done
# 86000/103877 done
# 86200/103877 done
# 86400/103877 done
# 86600/103877 done
# 86800/103877 done
# 87000/103877 done
# 87200/103877 done
# 87400/103877 done
# 87600/103877 done
# 87800/103877 done
# 88000/103877 done
# 88200/103877 done
# 88400/103877 done
# 88600/103877 done
# 88800/103877 done
# 89000/103877 done
# 89200/103877 done
# 89400/103877 done
# 89600/103877 done
# 89800/103877 done
# 90000/103877 done
# 90200/103877 done
# 90400/103877 done
# 90600/103877 done
# 90800/103877 done
# 91000/103877 done
# 91200/103877 done
# 91400/103877 done
# 91600/103877 done
# 91800/103877 done
# 92000/103877 done
# 92200/103877 done
# 92400/103877 done
# 92600/103877 done
# 92800/103877 done
# 93000/103877 done
# 93200/103877 done
# 93400/103877 done
# 93600/103877 done
# 93800/103877 done
# 94000/103877 done
# 94200/103877 done
# 94400/103877 done
# 94600/103877 done
# 94800/103877 done
# 95000/103877 done
# 95200/103877 done
# 95400/103877 done
# 95600/103877 done
# 95800/103877 done
# 96000/103877 done
# 96200/103877 done
# 96400/103877 done
# 96600/103877 done
# 96800/103877 done
# 97000/103877 done
# 97200/103877 done
# 97400/103877 done
# 97600/103877 done
# 97800/103877 done
# 98000/103877 done
# 98200/103877 done
# 98400/103877 done
# 98600/103877 done
# 98800/103877 done
# 99000/103877 done
# 99200/103877 done
# 99400/103877 done
# 99600/103877 done
# 99800/103877 done
# 100000/103877 done
# 100200/103877 done
# 100400/103877 done
# 100600/103877 done
# 100800/103877 done
# 101000/103877 done
# 101200/103877 done
# 101400/103877 done
# 101600/103877 done
# 101800/103877 done
# 102000/103877 done
# 102200/103877 done
# 102400/103877 done
# 102600/103877 done
# 102800/103877 done
# 103000/103877 done
# 103200/103877 done
# 103400/103877 done
# 103600/103877 done
# 103800/103877 done
# 103877/103877 done

# %%
# Define query to search for people based on their freebaseID

generic_query = """
SELECT (SAMPLE(?imdbID) AS ?imdbID)
       (SAMPLE(?wikidataID) AS ?wikidataID)
       # ?freebaseID
       (SAMPLE(?wikipediaLink) AS ?wikipediaLink)
       (SAMPLE(?itemLabel) AS ?nameSurname)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?givenNameLabel), ",", ""); SEPARATOR=",") AS ?givenName)
       (SAMPLE(?familyNameLabel) AS ?familyName)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?birthDates), ",", ""); SEPARATOR=",") AS ?birthDate)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?genderLabel), ",", ""); SEPARATOR=",") AS ?gender)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?citizenshipLabel), ",", ""); SEPARATOR=",") AS ?citizenship)
       (SAMPLE(?placeOfBirthLabel) AS ?placeOfBirth)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?nativeLanguageLabel), ",", ""); SEPARATOR=",") AS ?nativeLanguage)
       (GROUP_CONCAT(DISTINCT REPLACE(STR(?deathDates), ",", ""); SEPARATOR=",") AS ?deathDate)
WHERE {
  VALUES ?freebaseID {
|
  }

  # ?item wdt:P646 ?freebaseID .
  BIND(STR(?item) AS ?wikidataID)

  OPTIONAL { ?item wdt:P345 ?imdbID }

  OPTIONAL { ?item wdt:P735 ?givenName . ?givenName rdfs:label ?givenNameLabel FILTER(LANG(?givenNameLabel) = "en") }
  OPTIONAL { ?item wdt:P734 ?familyName . ?familyName rdfs:label ?familyNameLabel FILTER(LANG(?familyNameLabel) = "en") }

  OPTIONAL { ?item wdt:P569 ?birthDates }
  OPTIONAL { ?item wdt:P21 ?gender . ?gender rdfs:label ?genderLabel FILTER(LANG(?genderLabel) = "en") }
  OPTIONAL { ?item wdt:P27 ?citizenship . ?citizenship rdfs:label ?citizenshipLabel FILTER(LANG(?citizenshipLabel) = "en") }
  OPTIONAL { ?item wdt:P19 ?placeOfBirth . ?placeOfBirth rdfs:label ?placeOfBirthLabel FILTER(LANG(?placeOfBirthLabel) = "en") }
  OPTIONAL { ?item wdt:P103 ?nativeLanguage . ?nativeLanguage rdfs:label ?nativeLanguageLabel FILTER(LANG(?nativeLanguageLabel) = "en") }
  OPTIONAL { ?item wdt:P570 ?deathDates }

  OPTIONAL {
    # ?wikipediaLink schema:about ?item ;
                   schema:inLanguage "en" ;
                   schema:isPartOf <https://en.wikipedia.org/> .
  }

  # ?item rdfs:label ?itemLabel FILTER(LANG(?itemLabel) = "en") .
}
GROUP BY ?freebaseID
"""

# %%
# We run the above defined SPARQL query on groups of 200 freebaseIDs, the results are saved in temporary files

n = len(freebase_ids)
step = 200

c = 1
low = step*(c-1)
while low < n:
    up = min(low + step, n)

    ids_string = "\n".join([f"\"{freebase_ids[i]}\"" for i in range(low,up)])
    
    query = generic_query.replace("|", ids_string)
    
    success = download_wikidata_sparql_csv(query, f"{DATA_PATH}{temp_files_name}{521+c-1:06d}.csv")
    
    if success:
        low = up
        c += 1
        print(f"{up}/{n} done")
    else:
        print(f"{low} - {up} to redo")

    time.sleep(0.25)
# Out:
# 200/58275 done
# 400/58275 done
# 600/58275 done
# 800/58275 done
# 1000/58275 done
# 1200/58275 done
# 1400/58275 done
# 1600/58275 done
# 1800/58275 done
# 2000/58275 done
# 2200/58275 done
# 2400/58275 done
# 2600/58275 done
# 2800/58275 done
# 3000/58275 done
# 3200/58275 done
# 3400/58275 done
# 3600/58275 done
# 3800/58275 done
# 4000/58275 done
# 4200/58275 done
# 4400/58275 done
# 4600/58275 done
# 4800/58275 done
# 5000/58275 done
# 5200/58275 done
# 5400/58275 done
# 5600/58275 done
# 5800/58275 done
# 6000/58275 done
# 6200/58275 done
# 6400/58275 done
# 6600/58275 done
# 6800/58275 done
# 7000/58275 done
# 7200/58275 done
# 7400/58275 done
# 7600/58275 done
# 7800/58275 done
# 8000/58275 done
# 8200/58275 done
# 8400/58275 done
# 8600/58275 done
# 8800/58275 done
# 9000/58275 done
# 9200/58275 done
# 9400/58275 done
# 9600/58275 done
# 9800/58275 done
# 10000/58275 done
# 10200/58275 done
# 10400/58275 done
# 10600/58275 done
# 10800/58275 done
# 11000/58275 done
# 11200/58275 done
# 11400/58275 done
# 11600/58275 done
# 11800/58275 done
# 12000/58275 done
# 12200/58275 done
# 12400/58275 done
# 12600/58275 done
# 12800/58275 done
# 13000/58275 done
# 13200/58275 done
# 13400/58275 done
# 13600/58275 done
# 13800/58275 done
# 14000/58275 done
# 14200/58275 done
# 14400/58275 done
# 14600/58275 done
# 14800/58275 done
# 15000/58275 done
# 15200/58275 done
# 15400/58275 done
# 15600/58275 done
# 15800/58275 done
# 16000/58275 done
# 16200/58275 done
# 16400/58275 done
# 16600/58275 done
# 16800/58275 done
# 17000/58275 done
# 17200/58275 done
# 17400/58275 done
# 17600/58275 done
# 17800/58275 done
# 18000/58275 done
# 18200/58275 done
# 18400/58275 done
# 18600/58275 done
# 18800/58275 done
# 19000/58275 done
# 19200/58275 done
# 19400/58275 done
# 19600/58275 done
# 19800/58275 done
# 20000/58275 done
# 20200/58275 done
# 20400/58275 done
# 20600/58275 done
# 20800/58275 done
# 21000/58275 done
# 21200/58275 done
# 21400/58275 done
# 21600/58275 done
# 21800/58275 done
# 22000/58275 done
# 22200/58275 done
# 22400/58275 done
# 22600/58275 done
# 22800/58275 done
# 23000/58275 done
# 23200/58275 done
# 23400/58275 done
# 23600/58275 done
# 23800/58275 done
# 24000/58275 done
# 24200/58275 done
# 24400/58275 done
# 24600/58275 done
# 24800/58275 done
# 25000/58275 done
# 25200/58275 done
# 25400/58275 done
# 25600/58275 done
# 25800/58275 done
# 26000/58275 done
# 26200/58275 done
# 26400/58275 done
# 26600/58275 done
# 26800/58275 done
# 27000/58275 done
# 27200/58275 done
# 27400/58275 done
# 27600/58275 done
# 27800/58275 done
# 28000/58275 done
# 28200/58275 done
# 28400/58275 done
# 28600/58275 done
# 28800/58275 done
# 29000/58275 done
# 29200/58275 done
# 29400/58275 done
# 29600/58275 done
# 29800/58275 done
# 30000/58275 done
# 30200/58275 done
# 30400/58275 done
# 30600/58275 done
# 30800/58275 done
# 31000/58275 done
# 31200/58275 done
# 31400/58275 done
# 31600/58275 done
# 31800/58275 done
# 32000/58275 done
# 32200/58275 done
# 32400/58275 done
# 32600/58275 done
# 32800/58275 done
# 33000/58275 done
# 33200/58275 done
# 33400/58275 done
# 33600/58275 done
# 33800/58275 done
# 34000/58275 done
# 34200/58275 done
# 34400/58275 done
# 34600/58275 done
# 34800/58275 done
# 35000/58275 done
# 35200/58275 done
# 35400/58275 done
# 35600/58275 done
# 35800/58275 done
# 36000/58275 done
# 36200/58275 done
# 36400/58275 done
# 36600/58275 done
# 36800/58275 done
# 37000/58275 done
# 37200/58275 done
# 37400/58275 done
# 37600/58275 done
# 37800/58275 done
# 38000/58275 done
# 38200/58275 done
# 38400/58275 done
# 38600/58275 done
# 38800/58275 done
# 39000/58275 done
# 39200/58275 done
# 39400/58275 done
# 39600/58275 done
# 39800/58275 done
# 40000/58275 done
# 40200/58275 done
# 40400/58275 done
# 40600/58275 done
# 40800/58275 done
# 41000/58275 done
# 41200/58275 done
# 41400/58275 done
# 41600/58275 done
# 41800/58275 done
# 42000/58275 done
# 42200/58275 done
# 42400/58275 done
# 42600/58275 done
# 42800/58275 done
# 43000/58275 done
# 43200/58275 done
# 43400/58275 done
# 43600/58275 done
# 43800/58275 done
# 44000/58275 done
# 44200/58275 done
# 44400/58275 done
# 44600/58275 done
# 44800/58275 done
# 45000/58275 done
# 45200/58275 done
# 45400/58275 done
# 45600/58275 done
# 45800/58275 done
# 46000/58275 done
# 46200/58275 done
# 46400/58275 done
# 46600/58275 done
# 46800/58275 done
# 47000/58275 done
# 47200/58275 done
# 47400/58275 done
# 47600/58275 done
# 47800/58275 done
# 48000/58275 done
# 48200/58275 done
# 48400/58275 done
# 48600/58275 done
# 48800/58275 done
# 49000/58275 done
# 49200/58275 done
# 49400/58275 done
# 49600/58275 done
# 49800/58275 done
# 50000/58275 done
# 50200/58275 done
# 50400/58275 done
# 50600/58275 done
# 50800/58275 done
# 51000/58275 done
# 51200/58275 done
# 51400/58275 done
# 51600/58275 done
# 51800/58275 done
# 52000/58275 done
# 52200/58275 done
# 52400/58275 done
# 52600/58275 done
# 52800/58275 done
# 53000/58275 done
# 53200/58275 done
# 53400/58275 done
# 53600/58275 done
# 53800/58275 done
# 54000/58275 done
# 54200/58275 done
# 54400/58275 done
# 54600/58275 done
# 54800/58275 done
# 55000/58275 done
# 55200/58275 done
# 55400/58275 done
# 55600/58275 done
# 55800/58275 done
# 56000/58275 done
# 56200/58275 done
# 56400/58275 done
# 56600/58275 done
# 56800/58275 done
# 57000/58275 done
# 57200/58275 done
# 57400/58275 done
# 57600/58275 done
# 57800/58275 done
# 58000/58275 done
# 58200/58275 done
# 58275/58275 done

# %%
# Concatenate all the temporary files in a single csv file

pd.concat([pd.read_csv(f"{DATA_PATH}{temp_files_name}{i:06d}.csv") for i in range(1,813)], ignore_index=True).to_csv(DATA_PATH + "wikidata_people.csv", index=False)

# %%
# Define query to search for peoples' place of birth based on their wikidataID

generic_query = """
SELECT 
  # ?wikidataID
  (SAMPLE(?itemLabel) AS ?nameSurname)
  (SAMPLE(?placeOfBirthLabel) AS ?placeOfBirth)
  (SAMPLE(COALESCE(?countryLabel, ?originCountryLabel)) AS ?country)
  (SAMPLE(?continentLabel) AS ?continent)
WHERE {
  VALUES ?wikidataID {
|
  }

  # ?wikidataID rdfs:label ?itemLabel FILTER(LANG(?itemLabel) = "en") .
  
  OPTIONAL { 
    # ?wikidataID wdt:P19 ?placeOfBirth .
    # ?placeOfBirth rdfs:label ?placeOfBirthLabel FILTER(LANG(?placeOfBirthLabel) = "en") .
    OPTIONAL { 
      # ?placeOfBirth wdt:P17 ?country .
      # ?country rdfs:label ?countryLabel FILTER(LANG(?countryLabel) = "en") .
      OPTIONAL { 
        # ?country wdt:P30 ?continent .
        # ?continent rdfs:label ?continentLabel FILTER(LANG(?continentLabel) = "en") 
      }
    }
  }

  OPTIONAL {
    # ?wikidataID wdt:P495 ?originCountry .
    # ?originCountry rdfs:label ?originCountryLabel FILTER(LANG(?originCountryLabel) = "en") .
    OPTIONAL { 
        # ?originCountry wdt:P30 ?continent .
        # ?continent rdfs:label ?continentLabel FILTER(LANG(?continentLabel) = "en") 
      }
  }
}
GROUP BY ?wikidataID

"""

# %%
# We run the above defined SPARQL query on groups of 200 wikidataIDs, the results are saved in temporary files

def is_valid_format(string):
    return string.startswith('Q') and string[1:].isdigit()

people_complete = pd.read_csv(DATA_PATH + "people_complete.tsv", sep='\t')
wikidata_ids = people_complete.wikidata_id_actor.dropna()
wikidata_ids = wikidata_ids.apply(lambda x: x.split("/")[-1])
wikidata_ids = wikidata_ids[wikidata_ids.apply(is_valid_format)].values
wikidata_ids = list(wikidata_ids)

temp_files_name = "tempFiles/wikidata_people_country_temp_"

n = len(wikidata_ids)
step = 200

c = 1
low = step*(c-1)
while low < n:
    up = min(low + step, n)

    ids_string = "\n".join([f"wd:{wikidata_ids[i]}" for i in range(low,up)])
    
    query = generic_query.replace("|", ids_string)

    success = False
    try:
        success = download_wikidata_sparql_csv(query, f"{DATA_PATH}{temp_files_name}{c:06d}.csv")
    except:
        time.sleep(1)
    
    if success:
        low = up
        c += 1
        print(f"{up}/{n} done")
    else:
        print(f"{low} - {up} to redo")

    time.sleep(0.25)
# Out:
# 200/111500 done
# 400/111500 done
# 600/111500 done
# 800/111500 done
# 1000/111500 done
# 1200/111500 done
# 1400/111500 done
# 1600/111500 done
# 1800/111500 done
# 2000/111500 done
# 2200/111500 done
# 2400/111500 done
# 2600/111500 done
# 2800/111500 done
# 3000/111500 done
# 3200/111500 done
# 3400/111500 done
# 3600/111500 done
# 3800/111500 done
# 4000/111500 done
# 4200/111500 done
# 4400/111500 done
# 4600/111500 done
# 4800/111500 done
# 5000/111500 done
# 5200/111500 done
# 5400/111500 done
# 5600/111500 done
# 5800/111500 done
# 6000/111500 done
# 6200/111500 done
# 6400/111500 done
# 6600/111500 done
# 6800/111500 done
# 7000/111500 done
# 7200/111500 done
# 7400/111500 done
# 7600/111500 done
# 7800/111500 done
# 8000/111500 done
# 8200/111500 done
# 8400/111500 done
# 8600/111500 done
# 8800/111500 done
# 9000/111500 done
# 9200/111500 done
# 9400/111500 done
# 9600/111500 done
# 9800/111500 done
# 10000/111500 done
# 10200/111500 done
# 10400/111500 done
# 10600/111500 done
# 10800/111500 done
# 11000/111500 done
# 11200/111500 done
# 11400/111500 done
# 11600/111500 done
# 11800/111500 done
# 12000/111500 done
# 12200/111500 done
# 12400/111500 done
# 12600/111500 done
# 12800/111500 done
# 13000/111500 done
# 13200/111500 done
# 13400/111500 done
# 13600/111500 done
# 13800/111500 done
# 14000/111500 done
# 14200/111500 done
# 14400/111500 done
# 14600/111500 done
# 14800/111500 done
# 15000/111500 done
# 15200/111500 done
# 15400/111500 done
# 15600/111500 done
# 15800/111500 done
# 16000/111500 done
# 16200/111500 done
# 16400/111500 done
# 16600/111500 done
# 16800/111500 done
# 17000/111500 done
# 17200/111500 done
# 17400/111500 done
# 17600/111500 done
# 17800/111500 done
# 18000/111500 done
# 18200/111500 done
# 18400/111500 done
# 18600/111500 done
# 18800/111500 done
# 19000/111500 done
# 19200/111500 done
# 19400/111500 done
# 19600/111500 done
# 19800/111500 done
# 20000/111500 done
# 20200/111500 done
# 20400/111500 done
# 20600/111500 done
# 20800/111500 done
# 21000/111500 done
# 21200/111500 done
# 21400/111500 done
# 21600/111500 done
# 21800/111500 done
# 22000/111500 done
# 22200/111500 done
# 22400/111500 done
# 22600/111500 done
# 22800/111500 done
# 23000/111500 done
# 23200/111500 done
# 23400/111500 done
# 23600/111500 done
# 23800/111500 done
# 24000/111500 done
# 24200/111500 done
# 24400/111500 done
# 24600/111500 done
# 24800/111500 done
# 25000/111500 done
# 25200/111500 done
# 25400/111500 done
# 25600/111500 done
# 25800/111500 done
# 26000/111500 done
# 26200/111500 done
# 26400/111500 done
# 26600/111500 done
# 26800/111500 done
# 27000/111500 done
# 27200/111500 done
# 27400/111500 done
# 27600/111500 done
# 27800/111500 done
# 28000/111500 done
# 28200/111500 done
# 28400/111500 done
# 28600/111500 done
# 28800/111500 done
# 29000/111500 done
# 29200/111500 done
# 29400/111500 done
# 29600/111500 done
# 29800/111500 done
# 30000/111500 done
# 30200/111500 done
# 30400/111500 done
# 30600/111500 done
# 30800/111500 done
# 31000/111500 done
# 31200/111500 done
# 31400/111500 done
# 31600/111500 done
# 31800/111500 done
# 32000/111500 done
# 32200/111500 done
# 32400/111500 done
# 32600/111500 done
# 32800/111500 done
# 33000/111500 done
# 33200/111500 done
# 33400/111500 done
# 33600/111500 done
# 33800/111500 done
# 34000/111500 done
# 34200/111500 done
# 34400/111500 done
# 34600/111500 done
# 34800/111500 done
# 35000/111500 done
# 35200/111500 done
# 35400/111500 done
# 35600/111500 done
# 35800/111500 done
# 36000/111500 done
# 36200/111500 done
# 36400/111500 done
# 36600/111500 done
# 36800/111500 done
# 37000/111500 done
# 37200/111500 done
# 37400/111500 done
# 37600/111500 done
# 37800/111500 done
# 38000/111500 done
# 38200/111500 done
# 38400/111500 done
# 38600/111500 done
# 38800/111500 done
# 39000/111500 done
# 39200/111500 done
# 39400/111500 done
# 39600/111500 done
# 39800/111500 done
# 40000/111500 done
# 40200/111500 done
# 40400/111500 done
# 40600/111500 done
# 40800/111500 done
# 41000/111500 done
# 41200/111500 done
# 41400/111500 done
# 41600/111500 done
# 41800/111500 done
# 42000/111500 done
# 42200/111500 done
# 42400/111500 done
# 42600/111500 done
# 42800/111500 done
# 43000/111500 done
# 43200/111500 done
# 43400/111500 done
# 43600/111500 done
# 43800/111500 done
# 44000/111500 done
# 44200/111500 done
# 44400/111500 done
# 44600/111500 done
# 44800/111500 done
# 45000/111500 done
# 45200/111500 done
# 45400/111500 done
# 45600/111500 done
# 45800/111500 done
# 46000/111500 done
# 46200/111500 done
# 46400/111500 done
# 46600/111500 done
# 46800/111500 done
# 47000/111500 done
# 47200/111500 done
# 47400/111500 done
# 47600/111500 done
# 47800/111500 done
# 48000/111500 done
# 48200/111500 done
# 48400/111500 done
# 48600/111500 done
# 48800/111500 done
# 49000/111500 done
# 49200/111500 done
# 49400/111500 done
# 49600/111500 done
# 49800/111500 done
# 50000/111500 done
# 50200/111500 done
# 50400/111500 done
# 50600/111500 done
# 50800/111500 done
# 51000/111500 done
# 51200/111500 done
# 51400/111500 done
# 51600/111500 done
# 51800/111500 done
# 52000/111500 done
# 52200/111500 done
# 52400/111500 done
# 52600/111500 done
# 52800/111500 done
# 53000/111500 done
# 53200/111500 done
# 53400/111500 done
# 53600/111500 done
# 53800/111500 done
# 54000/111500 done
# 54200/111500 done
# 54400/111500 done
# 54600/111500 done
# 54800/111500 done
# 55000/111500 done
# 55200/111500 done
# 55400/111500 done
# 55600/111500 done
# 55800/111500 done
# 56000/111500 done
# 56200/111500 done
# 56400/111500 done
# 56600/111500 done
# 56800/111500 done
# 57000/111500 done
# 57200/111500 done
# 57400/111500 done
# 57600/111500 done
# 57800/111500 done
# 58000/111500 done
# 58200/111500 done
# 58400/111500 done
# 58600/111500 done
# 58800/111500 done
# 59000/111500 done
# 59200/111500 done
# 59400/111500 done
# 59600/111500 done
# 59800/111500 done
# 60000/111500 done
# 60200/111500 done
# 60400/111500 done
# 60600/111500 done
# 60800/111500 done
# 61000/111500 done
# 61200/111500 done
# 61400/111500 done
# 61600/111500 done
# 61800/111500 done
# 62000/111500 done
# 62200/111500 done
# 62400/111500 done
# 62600/111500 done
# 62800/111500 done
# 63000/111500 done
# 63200/111500 done
# 63400/111500 done
# 63600/111500 done
# 63800/111500 done
# 64000/111500 done
# 64200/111500 done
# 64400/111500 done
# 64600/111500 done
# 64800/111500 done
# 65000/111500 done
# 65200/111500 done
# 65400/111500 done
# 65600/111500 done
# 65800/111500 done
# 66000/111500 done
# 66200/111500 done
# 66400/111500 done
# 66600/111500 done
# 66800/111500 done
# 67000/111500 done
# 67200/111500 done
# 67400/111500 done
# 67600/111500 done
# 67800/111500 done
# 68000/111500 done
# 68200/111500 done
# 68400/111500 done
# 68600/111500 done
# 68800/111500 done
# 69000/111500 done
# 69200/111500 done
# 69400/111500 done
# 69600/111500 done
# 69800/111500 done
# 70000/111500 done
# 70200/111500 done
# 70400/111500 done
# 70600/111500 done
# 70800/111500 done
# 71000/111500 done
# 71200/111500 done
# 71400/111500 done
# 71600/111500 done
# 71800/111500 done
# 72000/111500 done
# 72200/111500 done
# 72400/111500 done
# 72600/111500 done
# 72800/111500 done
# 73000/111500 done
# 73200/111500 done
# 73400/111500 done
# 73600/111500 done
# 73800/111500 done
# 74000/111500 done
# 74200/111500 done
# 74400/111500 done
# 74600/111500 done
# 74800/111500 done
# 75000/111500 done
# 75200/111500 done
# 75400/111500 done
# 75600/111500 done
# 75800/111500 done
# 76000/111500 done
# 76200/111500 done
# 76400/111500 done
# 76600/111500 done
# 76800/111500 done
# 77000/111500 done
# 77200/111500 done
# 77400/111500 done
# 77600/111500 done
# 77800/111500 done
# 78000/111500 done
# 78200/111500 done
# 78400/111500 done
# 78600/111500 done
# 78800/111500 done
# 79000/111500 done
# 79200/111500 done
# 79400/111500 done
# 79600/111500 done
# 79800/111500 done
# 80000/111500 done
# 80200/111500 done
# 80400/111500 done
# 80600/111500 done
# 80800/111500 done
# 81000/111500 done
# 81200/111500 done
# 81400/111500 done
# 81600/111500 done
# 81800/111500 done
# 82000/111500 done
# 82200/111500 done
# 82400/111500 done
# 82600/111500 done
# 82800/111500 done
# 83000/111500 done
# 83200/111500 done
# 83400/111500 done
# 83600/111500 done
# 83800/111500 done
# 84000/111500 done
# 84200/111500 done
# 84400/111500 done
# 84600/111500 done
# 84800/111500 done
# 85000/111500 done
# 85200/111500 done
# 85400/111500 done
# 85600/111500 done
# 85800/111500 done
# 86000/111500 done
# 86200/111500 done
# 86400/111500 done
# 86600/111500 done
# 86800/111500 done
# 87000/111500 done
# 87200/111500 done
# 87400/111500 done
# 87600/111500 done
# 87800/111500 done
# 88000/111500 done
# 88200/111500 done
# 88400/111500 done
# 88600/111500 done
# 88800/111500 done
# 89000/111500 done
# 89200/111500 done
# 89400/111500 done
# 89600/111500 done
# 89800/111500 done
# 90000/111500 done
# 90200/111500 done
# 90400/111500 done
# 90600/111500 done
# 90800/111500 done
# 91000/111500 done
# 91200/111500 done
# 91400/111500 done
# 91600/111500 done
# 91800/111500 done
# 92000/111500 done
# 92200/111500 done
# 92400/111500 done
# 92600/111500 done
# 92800/111500 done
# 93000/111500 done
# 93200/111500 done
# 93400/111500 done
# 93600/111500 done
# 93800/111500 done
# 94000/111500 done
# 94200/111500 done
# 94400/111500 done
# 94600/111500 done
# 94800/111500 done
# 95000/111500 done
# 95200/111500 done
# 95400/111500 done
# 95600/111500 done
# 95800/111500 done
# 96000/111500 done
# 96200/111500 done
# 96400/111500 done
# 96600/111500 done
# 96800/111500 done
# 97000/111500 done
# 97200/111500 done
# 97400/111500 done
# 97600/111500 done
# 97800/111500 done
# 98000/111500 done
# 98200/111500 done
# 98400/111500 done
# 98600/111500 done
# 98800/111500 done
# 99000/111500 done
# 99200/111500 done
# 99400/111500 done
# 99600/111500 done
# 99800/111500 done
# 100000/111500 done
# 100200/111500 done
# 100400/111500 done
# 100600/111500 done
# 100800/111500 done
# 101000/111500 done
# 101200/111500 done
# 101400/111500 done
# 101600/111500 done
# 101800/111500 done
# 102000/111500 done
# 102200/111500 done
# 102400/111500 done
# 102600/111500 done
# 102800/111500 done
# 103000/111500 done
# 103200/111500 done
# 103400/111500 done
# 103600/111500 done
# 103800/111500 done
# 104000/111500 done
# 104200/111500 done
# 104400/111500 done
# 104600/111500 done
# 104800/111500 done
# 105000/111500 done
# 105200/111500 done
# 105400/111500 done
# 105600/111500 done
# 105800/111500 done
# 106000/111500 done
# 106200/111500 done
# 106400/111500 done
# 106600/111500 done
# 106800/111500 done
# 107000/111500 done
# 107200/111500 done
# 107400/111500 done
# 107600/111500 done
# 107800/111500 done
# 108000/111500 done
# 108200/111500 done
# 108400/111500 done
# 108600/111500 done
# 108800/111500 done
# 109000/111500 done
# 109200/111500 done
# 109400/111500 done
# 109600/111500 done
# 109800/111500 done
# 110000/111500 done
# 110200/111500 done
# 110400/111500 done
# 110600/111500 done
# 110800/111500 done
# 111000/111500 done
# 111200/111500 done
# 111400/111500 done
# 111500/111500 done

# %%
# Concatenate all the temporary files in a single csv file

pd.concat([pd.read_csv(f"{DATA_PATH}{temp_files_name}{i:06d}.csv") for i in range(1,559)], ignore_index=True).to_csv(DATA_PATH + "wikidata_people_country.csv", index=False)
